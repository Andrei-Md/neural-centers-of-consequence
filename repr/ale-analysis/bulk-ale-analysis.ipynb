# %%
# %matplotlib inline

# %% [markdown]
# # ALE meta-analysis

# %%
import os
from os import listdir
from os.path import isfile, join
import nibabel as nib
from pathlib import Path

import matplotlib.pyplot as plt
from nilearn.plotting import plot_stat_map
from nimare.io import convert_sleuth_to_dataset
from nimare.utils import get_resource_path

from nimare.correct import FWECorrector
from nimare.meta.cbma import ALE

# %%
_dset_folder = r'../data_db/dataset_ale/'
_nii_folder = r'../data_db/nifti-ale/'
_res_folder = r'../data_db/res/'
_nii_combos_folder = r'../data_db/nifti-ale/combos/'

# %% [markdown]
# ## ALE Working Memory: visual task stimulus and task modality n-task

# %%
dsetfiles = {Path(f).stem: f for f in listdir(_dset_folder) if isfile(join(_dset_folder, f))}

# %%
files = {k: os.path.join(os.path.abspath(_dset_folder), file_name) for k, file_name in dsetfiles.items()}
dsets = {k: convert_sleuth_to_dataset(f) for k, f in files.items()}

# %%
corrected_results = {}
# ale = ALE(null_method="montecarlo",n_iters=100,n_cores=8)
ale = ALE(null_method="approximate")
corr = FWECorrector(method="montecarlo", voxel_thresh=0.001, n_iters=100, n_cores=8)
for index, (k, dset) in enumerate(dsets.items()):
    result = ale.fit(dset)
    corrected_results[k] = corr.transform(result)
# Out:
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:06<00:00, 15.56it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:04<00:00, 20.44it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:03<00:00, 28.85it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:04<00:00, 22.69it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:04<00:00, 22.16it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:03<00:00, 30.59it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:04<00:00, 23.73it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:03<00:00, 29.21it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:04<00:00, 22.60it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:03<00:00, 26.42it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:06<00:00, 15.70it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:04<00:00, 24.95it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:03<00:00, 26.86it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.

# %%
## Check
map_name = "z_desc-size_level-cluster_corr-FWE_method-montecarlo"
imgs = {}
res_len = len(corrected_results)
fig, axes = plt.subplots(figsize=(12, res_len * 10), nrows=res_len)
for index, (k, corr_result) in enumerate(corrected_results.items()):
    imgs[k] = corr_result.get_map(
        map_name
    )

    plot_stat_map(
        imgs[k],
        cut_coords=4,
        display_mode="z",
        title="Semantic select " + str(index),
        threshold=2.326,  #'auto' # cluster-level p < .01, one-tailed
        cmap="RdBu_r",
        vmax=4,
        axes=axes[index],
        figure=fig,
    )
# Out:
# C:\ProgramData\Anaconda3\envs\tfg-env\lib\site-packages\nilearn\plotting\displays\_slicers.py:383: UserWarning: empty mask
#   get_mask_bounds(new_img_like(img, not_mask, affine))

# %% [markdown]
# ## Save images to nifti

# %%
for index, (file_name, img) in enumerate(imgs.items()):
    nib.save(img, os.path.join(os.path.abspath(_nii_folder), file_name + '.nii'))
    nib.save(corrected_results[file_name].get_map('z'),
             os.path.join(os.path.abspath(_nii_folder), file_name + '-z.nii'))

# %% [markdown]
# ## Statistics

# %%
from IPython.display import display
from nimare.diagnostics import FocusCounter

counter = FocusCounter(
    target_image="z_desc-size_level-cluster_corr-FWE_method-montecarlo",
    voxel_thresh=None,
)
for index, (file_name, corr_res) in enumerate(corrected_results.items()):
    print(file_name)
    count_table, _ = counter.transform(corr_res)
    print(count_table.shape)
    display(count_table)
# Out:
# WARNING:nimare.diagnostics:No clusters found
# select00_test
# (2, 0)
# Empty DataFrame
# Columns: []
# Index: [Center of Mass, Test test test-]
# select01_wm
# 100%|██████████| 12/12 [00:00<00:00, 31.80it/s]
# (13, 13)
#                                                                1   \
# Cluster ID
# Center of Mass                                      (44, -47, 44)
# Beneventi et al-An fMRI study of working memor..                0
# Carrion et al-Frontal Hypoactivation on Func..                  2
# Di et al-Anterior cingulate cortex diff..                       0
# Drobyshevsky et al-A Rapid fMRI Task Battery fo...              1
# Duggirala et al-Stimulus-dependent modulation ..                0
# Lee et al-Abnormal neural activity in pa..                      1
# Padilla et al-Long-term brain effects of N-b..                  3
# Pochon et al-The neural system that bridges..                   0
# Rodger et al-Inhibit  switch  and update - ..                   2
# Schmidt et al-No gender differences in brain..                  0
# Seo et al-Working Memory Impairment in F..                      1
# Taylor et al-A functional neuroimaging stud..                   0
#
#                                                               2            3   \
# Cluster ID
# Center of Mass                                      (39, 43, 20)  (31, 5, 54)
# Beneventi et al-An fMRI study of working memor..               0            1
# Carrion et al-Frontal Hypoactivation on Func..                 1            0
# Di et al-Anterior cingulate cortex diff..                      0            1
# Drobyshevsky et al-A Rapid fMRI Task Battery fo...             0            1
# Duggirala et al-Stimulus-dependent modulation ..               2            0
# Lee et al-Abnormal neural activity in pa..                     0            0
# Padilla et al-Long-term brain effects of N-b..                 0            1
# Pochon et al-The neural system that bridges..                  0            0
# Rodger et al-Inhibit  switch  and update - ..                  1            2
# Schmidt et al-No gender differences in brain..                 0            1
# Seo et al-Working Memory Impairment in F..                     0            1
# Taylor et al-A functional neuroimaging stud..                  2            1
#
#                                                               4   \
# Cluster ID
# Center of Mass                                      (32, 22, -1)
# Beneventi et al-An fMRI study of working memor..               1
# Carrion et al-Frontal Hypoactivation on Func..                 2
# Di et al-Anterior cingulate cortex diff..                      0
# Drobyshevsky et al-A Rapid fMRI Task Battery fo...             0
# Duggirala et al-Stimulus-dependent modulation ..               6
# Lee et al-Abnormal neural activity in pa..                     1
# Padilla et al-Long-term brain effects of N-b..                 0
# Pochon et al-The neural system that bridges..                  0
# Rodger et al-Inhibit  switch  and update - ..                  0
# Schmidt et al-No gender differences in brain..                 0
# Seo et al-Working Memory Impairment in F..                     1
# Taylor et al-A functional neuroimaging stud..                  0
#
#                                                                5   \
# Cluster ID
# Center of Mass                                      (20, -67, 53)
# Beneventi et al-An fMRI study of working memor..                0
# Carrion et al-Frontal Hypoactivation on Func..                  1
# Di et al-Anterior cingulate cortex diff..                       1
# Drobyshevsky et al-A Rapid fMRI Task Battery fo...              1
# Duggirala et al-Stimulus-dependent modulation ..                0
# Lee et al-Abnormal neural activity in pa..                      0
# Padilla et al-Long-term brain effects of N-b..                  0
# Pochon et al-The neural system that bridges..                   0
# Rodger et al-Inhibit  switch  and update - ..                   0
# Schmidt et al-No gender differences in brain..                  1
# Seo et al-Working Memory Impairment in F..                      0
# Taylor et al-A functional neuroimaging stud..                   0
#
#                                                              6   \
# Cluster ID
# Center of Mass                                      (1, 19, 46)
# Beneventi et al-An fMRI study of working memor..              1
# Carrion et al-Frontal Hypoactivation on Func..                1
# Di et al-Anterior cingulate cortex diff..                     0
# Drobyshevsky et al-A Rapid fMRI Task Battery fo...            1
# Duggirala et al-Stimulus-dependent modulation ..              4
# Lee et al-Abnormal neural activity in pa..                    3
# Padilla et al-Long-term brain effects of N-b..                3
# Pochon et al-The neural system that bridges..                 0
# Rodger et al-Inhibit  switch  and update - ..                 0
# Schmidt et al-No gender differences in brain..                2
# Seo et al-Working Memory Impairment in F..                    4
# Taylor et al-A functional neuroimaging stud..                 3
#
#                                                                 7   \
# Cluster ID
# Center of Mass                                      (-22, -66, 44)
# Beneventi et al-An fMRI study of working memor..                 0
# Carrion et al-Frontal Hypoactivation on Func..                   2
# Di et al-Anterior cingulate cortex diff..                        1
# Drobyshevsky et al-A Rapid fMRI Task Battery fo...               1
# Duggirala et al-Stimulus-dependent modulation ..                 0
# Lee et al-Abnormal neural activity in pa..                       1
# Padilla et al-Long-term brain effects of N-b..                   0
# Pochon et al-The neural system that bridges..                    0
# Rodger et al-Inhibit  switch  and update - ..                    0
# Schmidt et al-No gender differences in brain..                   0
# Seo et al-Working Memory Impairment in F..                       1
# Taylor et al-A functional neuroimaging stud..                    0
#
#                                                               8   \
# Cluster ID
# Center of Mass                                      (-27, 2, 53)
# Beneventi et al-An fMRI study of working memor..               0
# Carrion et al-Frontal Hypoactivation on Func..                 2
# Di et al-Anterior cingulate cortex diff..                      1
# Drobyshevsky et al-A Rapid fMRI Task Battery fo...             1
# Duggirala et al-Stimulus-dependent modulation ..               1
# Lee et al-Abnormal neural activity in pa..                     2
# Padilla et al-Long-term brain effects of N-b..                 2
# Pochon et al-The neural system that bridges..                  0
# Rodger et al-Inhibit  switch  and update - ..                  0
# Schmidt et al-No gender differences in brain..                 1
# Seo et al-Working Memory Impairment in F..                     0
# Taylor et al-A functional neuroimaging stud..                  2
#
#                                                                9   \
# Cluster ID
# Center of Mass                                      (-31, 22, -1)
# Beneventi et al-An fMRI study of working memor..                1
# Carrion et al-Frontal Hypoactivation on Func..                  2
# Di et al-Anterior cingulate cortex diff..                       1
# Drobyshevsky et al-A Rapid fMRI Task Battery fo...              0
# Duggirala et al-Stimulus-dependent modulation ..                4
# Lee et al-Abnormal neural activity in pa..                      1
# Padilla et al-Long-term brain effects of N-b..                  1
# Pochon et al-The neural system that bridges..                   0
# Rodger et al-Inhibit  switch  and update - ..                   1
# Schmidt et al-No gender differences in brain..                  1
# Seo et al-Working Memory Impairment in F..                      1
# Taylor et al-A functional neuroimaging stud..                   0
#
#                                                                 10  \
# Cluster ID
# Center of Mass                                      (-37, -52, 46)
# Beneventi et al-An fMRI study of working memor..                 1
# Carrion et al-Frontal Hypoactivation on Func..                   3
# Di et al-Anterior cingulate cortex diff..                        0
# Drobyshevsky et al-A Rapid fMRI Task Battery fo...               1
# Duggirala et al-Stimulus-dependent modulation ..                 9
# Lee et al-Abnormal neural activity in pa..                       2
# Padilla et al-Long-term brain effects of N-b..                   1
# Pochon et al-The neural system that bridges..                    0
# Rodger et al-Inhibit  switch  and update - ..                    1
# Schmidt et al-No gender differences in brain..                   1
# Seo et al-Working Memory Impairment in F..                       1
# Taylor et al-A functional neuroimaging stud..                    2
#
#                                                               11  \
# Cluster ID
# Center of Mass                                      (-36, 51, 5)
# Beneventi et al-An fMRI study of working memor..               0
# Carrion et al-Frontal Hypoactivation on Func..                 2
# Di et al-Anterior cingulate cortex diff..                      2
# Drobyshevsky et al-A Rapid fMRI Task Battery fo...             0
# Duggirala et al-Stimulus-dependent modulation ..               0
# Lee et al-Abnormal neural activity in pa..                     2
# Padilla et al-Long-term brain effects of N-b..                 1
# Pochon et al-The neural system that bridges..                  0
# Rodger et al-Inhibit  switch  and update - ..                  1
# Schmidt et al-No gender differences in brain..                 0
# Seo et al-Working Memory Impairment in F..                     0
# Taylor et al-A functional neuroimaging stud..                  2
#
#                                                                12  \
# Cluster ID
# Center of Mass                                      (-41, 23, 27)
# Beneventi et al-An fMRI study of working memor..                0
# Carrion et al-Frontal Hypoactivation on Func..                  0
# Di et al-Anterior cingulate cortex diff..                       0
# Drobyshevsky et al-A Rapid fMRI Task Battery fo...              1
# Duggirala et al-Stimulus-dependent modulation ..                4
# Lee et al-Abnormal neural activity in pa..                      0
# Padilla et al-Long-term brain effects of N-b..                  1
# Pochon et al-The neural system that bridges..                   0
# Rodger et al-Inhibit  switch  and update - ..                   0
# Schmidt et al-No gender differences in brain..                  0
# Seo et al-Working Memory Impairment in F..                      0
# Taylor et al-A functional neuroimaging stud..                   0
#
#                                                               13
# Cluster ID
# Center of Mass                                      (-44, 6, 28)
# Beneventi et al-An fMRI study of working memor..               1
# Carrion et al-Frontal Hypoactivation on Func..                 0
# Di et al-Anterior cingulate cortex diff..                      1
# Drobyshevsky et al-A Rapid fMRI Task Battery fo...             0
# Duggirala et al-Stimulus-dependent modulation ..               4
# Lee et al-Abnormal neural activity in pa..                     1
# Padilla et al-Long-term brain effects of N-b..                 1
# Pochon et al-The neural system that bridges..                  0
# Rodger et al-Inhibit  switch  and update - ..                  0
# Schmidt et al-No gender differences in brain..                 0
# Seo et al-Working Memory Impairment in F..                     1
# Taylor et al-A functional neuroimaging stud..                  0
# select02_wm_decision-making
# 100%|██████████| 3/3 [00:00<00:00, 96.68it/s]
# (4, 2)
#                                                             1               2
# Cluster ID
# Center of Mass                                  (28, -68, 47)  (-15, -65, 56)
# Cruz et al-Alterations in the functional ..                 1               1
# Nobre et al-Orienting Attention to Locatio..                3               3
# Reilhac et al-Role of the superior parietal ..              2               2
# select03_reward_anticipation_rw-norw
# 100%|██████████| 8/8 [00:00<00:00, 61.48it/s]
# (9, 5)
#                                                                1           2  \
# Cluster ID
# Center of Mass                                      (40, 20, -8)  (11, 3, 0)
# Cohen et al-Individual differences in extr..                   0           1
# John O Doherty et al-Neural Responses during An...             0           0
# Kirscg et al-Anticipation of reward in a no..                  2           5
# Knutson et al-A region of mesial prefrontal ..                 1           3
# Knutson et al-Anticipation of Increasing Mon..                 0           3
# Knutson et al-Dissociation of reward anticip..                 1           3
# Koeneke et al-Individual preferences modulat..                 1           0
# Spreckelmeyer et al-Anticipation of monetary an...             0           5
#
#                                                               3           4  \
# Cluster ID
# Center of Mass                                      (6, 21, 35)  (3, 1, 48)
# Cohen et al-Individual differences in extr..                  0           0
# John O Doherty et al-Neural Responses during An...            0           0
# Kirscg et al-Anticipation of reward in a no..                 1           0
# Knutson et al-A region of mesial prefrontal ..                1           1
# Knutson et al-Anticipation of Increasing Mon..                2           1
# Knutson et al-Dissociation of reward anticip..                1           1
# Koeneke et al-Individual preferences modulat..                0           0
# Spreckelmeyer et al-Anticipation of monetary an...            0           0
#
#                                                                5
# Cluster ID
# Center of Mass                                      (-11, 7, -7)
# Cohen et al-Individual differences in extr..                   0
# John O Doherty et al-Neural Responses during An...             0
# Kirscg et al-Anticipation of reward in a no..                  3
# Knutson et al-A region of mesial prefrontal ..                 2
# Knutson et al-Anticipation of Increasing Mon..                 1
# Knutson et al-Dissociation of reward anticip..                 3
# Koeneke et al-Individual preferences modulat..                 0
# Spreckelmeyer et al-Anticipation of monetary an...             4
# select04_reward_anticipation_high_low_rew
# 100%|██████████| 8/8 [00:00<00:00, 57.09it/s]
# (9, 6)
#                                                                1  \
# Cluster ID
# Center of Mass                                      (28, 22, -2)
# Abler et al-From uncertainty to reward - B..                   0
# Croxson et al-Effort-Based Cost Benefit Valu..                 1
# Jarcho et al-Developmental effects of decis..                  0
# Knutson et al-Anticipation of Increasing Mon..                 0
# Knutson et al-Distributed Neural Representat..                 1
# Smith et al-Neural substrates of reward ma..                   0
# Spreckelmeyer et al-Anticipation of monetary an...             1
# Tobler et al-Reward Value Coding Distinct F..                  0
#
#                                                                2            3  \
# Cluster ID
# Center of Mass                                      (12, 10, -3)  (2, 24, 28)
# Abler et al-From uncertainty to reward - B..                   1            1
# Croxson et al-Effort-Based Cost Benefit Valu..                 1            0
# Jarcho et al-Developmental effects of decis..                  0            0
# Knutson et al-Anticipation of Increasing Mon..                 2            2
# Knutson et al-Distributed Neural Representat..                 3            1
# Smith et al-Neural substrates of reward ma..                   0            0
# Spreckelmeyer et al-Anticipation of monetary an...             6            2
# Tobler et al-Reward Value Coding Distinct F..                  1            0
#
#                                                                4  \
# Cluster ID
# Center of Mass                                      (-11, 8, -2)
# Abler et al-From uncertainty to reward - B..                   3
# Croxson et al-Effort-Based Cost Benefit Valu..                 1
# Jarcho et al-Developmental effects of decis..                  1
# Knutson et al-Anticipation of Increasing Mon..                 2
# Knutson et al-Distributed Neural Representat..                 3
# Smith et al-Neural substrates of reward ma..                   0
# Spreckelmeyer et al-Anticipation of monetary an...             7
# Tobler et al-Reward Value Coding Distinct F..                  2
#
#                                                                   5  \
# Cluster ID
# Center of Mass                                      (-20, -14, -14)
# Abler et al-From uncertainty to reward - B..                      0
# Croxson et al-Effort-Based Cost Benefit Valu..                    0
# Jarcho et al-Developmental effects of decis..                     0
# Knutson et al-Anticipation of Increasing Mon..                    0
# Knutson et al-Distributed Neural Representat..                    1
# Smith et al-Neural substrates of reward ma..                      2
# Spreckelmeyer et al-Anticipation of monetary an...                0
# Tobler et al-Reward Value Coding Distinct F..                     1
#
#                                                                 6
# Cluster ID
# Center of Mass                                      (-31, 19, -2)
# Abler et al-From uncertainty to reward - B..                    0
# Croxson et al-Effort-Based Cost Benefit Valu..                  1
# Jarcho et al-Developmental effects of decis..                   1
# Knutson et al-Anticipation of Increasing Mon..                  0
# Knutson et al-Distributed Neural Representat..                  2
# Smith et al-Neural substrates of reward ma..                    0
# Spreckelmeyer et al-Anticipation of monetary an...              0
# Tobler et al-Reward Value Coding Distinct F..                   0
# select05_reward_anticipation_exp_recv_rew
# 100%|██████████| 3/3 [00:00<00:00, 119.89it/s]
# (4, 1)
#                                                                1
# Cluster ID
# Center of Mass                                      (-32, 32, 3)
# John O Doherty et al-Neural Responses during An...             0
# Rademacher et al-Dissociation of neural network..              1
# Tobler et al-Reward Value Coding Distinct F..                  1
# select06_reward_outcome_rw-norw
# 100%|██████████| 10/10 [00:00<00:00, 71.36it/s]
# (11, 4)
#                                                                 1  \
# Cluster ID
# Center of Mass                                      (28, -3, -23)
# Cohen et al-Individual differences in extr..                    1
# Elliott et al-Differential Response Patterns..                  1
# Elliott et al-Instrumental responding for re..                  2
# John O Doherty et al-Neural Responses during An...              0
# Knutson et al-A region of mesial prefrontal ..                  0
# Knutson et al-Dissociation of reward anticip..                  0
# Koeneke et al-Individual preferences modulat..                  0
# Schienle et al-Binge-Eating Disorder  Reward ..                 1
# Sescousse et al-The Architecture of Reward Val..                0
# Smith et al-Distinct Value Signals in Ante..                    0
#
#                                                                 2  \
# Cluster ID
# Center of Mass                                      (27, 24, -20)
# Cohen et al-Individual differences in extr..                    1
# Elliott et al-Differential Response Patterns..                  0
# Elliott et al-Instrumental responding for re..                  0
# John O Doherty et al-Neural Responses during An...              0
# Knutson et al-A region of mesial prefrontal ..                  0
# Knutson et al-Dissociation of reward anticip..                  0
# Koeneke et al-Individual preferences modulat..                  0
# Schienle et al-Binge-Eating Disorder  Reward ..                 3
# Sescousse et al-The Architecture of Reward Val..                0
# Smith et al-Distinct Value Signals in Ante..                    0
#
#                                                                 3            4
# Cluster ID
# Center of Mass                                      (3, -19, -22)  (0, 48, -7)
# Cohen et al-Individual differences in extr..                    0            0
# Elliott et al-Differential Response Patterns..                  0            0
# Elliott et al-Instrumental responding for re..                  1            1
# John O Doherty et al-Neural Responses during An...              0            0
# Knutson et al-A region of mesial prefrontal ..                  0            0
# Knutson et al-Dissociation of reward anticip..                  0            0
# Koeneke et al-Individual preferences modulat..                  1            0
# Schienle et al-Binge-Eating Disorder  Reward ..                 0            0
# Sescousse et al-The Architecture of Reward Val..                1            0
# Smith et al-Distinct Value Signals in Ante..                    0            2
# WARNING:nimare.diagnostics:No clusters found
# select07_reward_outcome_risk-safe
# (4, 0)
# Empty DataFrame
# Columns: []
# Index: [Center of Mass, Abler et al-From uncertainty to reward - B.., Lawrence et al-Distinct Roles of Prefrontal C.., Xue et al-Functional Dissociations of Ri..]
# select08_reward_outcome_high-low
# 100%|██████████| 9/9 [00:00<00:00, 98.81it/s]
# (10, 2)
#                                                              1             2
# Cluster ID
# Center of Mass                                      (1, 36, 9)  (0, -32, 30)
# Abler et al-From uncertainty to reward - B..                 0             0
# Cloutier et al-Are Attractive People Rewardin..              2             0
# Delgado et al-Dorsal striatum responses to r..               0             0
# Elliott et al-Dissociable Neural Responses i..               0             0
# Jarcho et al-Developmental effects of decis..                0             1
# Knutson et al-Dissociation of reward anticip..               0             0
# Nieuwenhuis et al-Activity in human reward-sensi..           0             1
# Signe Bray and John O'Doherty-Neural Coding of ...           1             1
# Winston et al-Brain systems for assessing fa..               1             0
# select09_reward_outcome_win-lose
# 100%|██████████| 6/6 [00:00<00:00, 83.26it/s]
# (7, 3)
#                                                                1  \
# Cluster ID
# Center of Mass                                     (33, -59, 39)
# Christakou et al-Right Ventromedial and Dorsola..              0
# Fujiwara et al-Segregated and Integrated Codi..                1
# Greck et al-Is our self based on reward - ..                   0
# Lawrence et al-Distinct Roles of Prefrontal C..                0
# Vassena et al-Dissociating contributions of ..                 1
# Xue et al-Functional Dissociations of Ri..                     1
#
#                                                               2            3
# Cluster ID
# Center of Mass                                     (16, 11, -7)  (-4, 37, 6)
# Christakou et al-Right Ventromedial and Dorsola..             0            0
# Fujiwara et al-Segregated and Integrated Codi..               0            2
# Greck et al-Is our self based on reward - ..                  1            0
# Lawrence et al-Distinct Roles of Prefrontal C..               0            0
# Vassena et al-Dissociating contributions of ..                4            1
# Xue et al-Functional Dissociations of Ri..                    1            1
# select10_reward_decision-making_outcome
# 100%|██████████| 22/22 [00:00<00:00, 61.92it/s]
# (23, 5)
#                                                                1  \
# Cluster ID
# Center of Mass                                      (32, 25, -2)
# Abler et al-From uncertainty to reward - B..                   1
# Akitsuki et al-Context-dependent cortical act..                0
# Christakou et al-Right Ventromedial and Dorsola..              0
# Cohen et al-Individual differences in extr..                   0
# Cox et al-Learning to Like  A Role for H..                     0
# Delgado et al-Tracking the Hemodynamic Respo..                 0
# Elliott et al-Dissociable Neural Responses i..                 0
# Elliott et al-Instrumental responding for re..                 0
# Glascher et al-Determining a Role for Ventrom..                1
# Greck et al-Is our self based on reward - ..                   0
# Hauser et al-Role of the Medial Prefrontal ..                  0
# Jarcho et al-Developmental effects of decis..                  3
# John O Doherty-Dissociating Valence of Outcom..                0
# Koeneke et al-Individual preferences modulat..                 0
# Lawrence et al-Distinct Roles of Prefrontal C..                1
# Nieuwenhuis et al-Activity in human reward-sensi..             0
# Schonberg et al-Decreasing ventromedial prefro..               0
# Sescousse et al-The Architecture of Reward Val..               1
# Smith et al-Distinct Value Signals in Ante..                   1
# Vassena et al-Dissociating contributions of ..                 2
# Winston et al-Brain systems for assessing fa..                 0
# Xue et al-Functional Dissociations of Ri..                     0
#
#                                                                2  \
# Cluster ID
# Center of Mass                                      (15, 11, -3)
# Abler et al-From uncertainty to reward - B..                   1
# Akitsuki et al-Context-dependent cortical act..                0
# Christakou et al-Right Ventromedial and Dorsola..              0
# Cohen et al-Individual differences in extr..                   1
# Cox et al-Learning to Like  A Role for H..                     0
# Delgado et al-Tracking the Hemodynamic Respo..                 2
# Elliott et al-Dissociable Neural Responses i..                 0
# Elliott et al-Instrumental responding for re..                 0
# Glascher et al-Determining a Role for Ventrom..                0
# Greck et al-Is our self based on reward - ..                   2
# Hauser et al-Role of the Medial Prefrontal ..                  0
# Jarcho et al-Developmental effects of decis..                  1
# John O Doherty-Dissociating Valence of Outcom..                2
# Koeneke et al-Individual preferences modulat..                 1
# Lawrence et al-Distinct Roles of Prefrontal C..                0
# Nieuwenhuis et al-Activity in human reward-sensi..             0
# Schonberg et al-Decreasing ventromedial prefro..               0
# Sescousse et al-The Architecture of Reward Val..               0
# Smith et al-Distinct Value Signals in Ante..                   0
# Vassena et al-Dissociating contributions of ..                 4
# Winston et al-Brain systems for assessing fa..                 0
# Xue et al-Functional Dissociations of Ri..                     1
#
#                                                                3  \
# Cluster ID
# Center of Mass                                      (-1, 49, -7)
# Abler et al-From uncertainty to reward - B..                   1
# Akitsuki et al-Context-dependent cortical act..                2
# Christakou et al-Right Ventromedial and Dorsola..              0
# Cohen et al-Individual differences in extr..                   0
# Cox et al-Learning to Like  A Role for H..                     0
# Delgado et al-Tracking the Hemodynamic Respo..                 0
# Elliott et al-Dissociable Neural Responses i..                 1
# Elliott et al-Instrumental responding for re..                 1
# Glascher et al-Determining a Role for Ventrom..                1
# Greck et al-Is our self based on reward - ..                   0
# Hauser et al-Role of the Medial Prefrontal ..                  0
# Jarcho et al-Developmental effects of decis..                  0
# John O Doherty-Dissociating Valence of Outcom..                0
# Koeneke et al-Individual preferences modulat..                 0
# Lawrence et al-Distinct Roles of Prefrontal C..                2
# Nieuwenhuis et al-Activity in human reward-sensi..             0
# Schonberg et al-Decreasing ventromedial prefro..               1
# Sescousse et al-The Architecture of Reward Val..               1
# Smith et al-Distinct Value Signals in Ante..                   6
# Vassena et al-Dissociating contributions of ..                 0
# Winston et al-Brain systems for assessing fa..                 0
# Xue et al-Functional Dissociations of Ri..                     3
#
#                                                                4             5
# Cluster ID
# Center of Mass                                      (-2, 54, 14)  (-14, 9, -5)
# Abler et al-From uncertainty to reward - B..                   0             3
# Akitsuki et al-Context-dependent cortical act..                2             1
# Christakou et al-Right Ventromedial and Dorsola..              0             1
# Cohen et al-Individual differences in extr..                   0             1
# Cox et al-Learning to Like  A Role for H..                     0             1
# Delgado et al-Tracking the Hemodynamic Respo..                 0             4
# Elliott et al-Dissociable Neural Responses i..                 0             1
# Elliott et al-Instrumental responding for re..                 0             0
# Glascher et al-Determining a Role for Ventrom..                0             0
# Greck et al-Is our self based on reward - ..                   1             1
# Hauser et al-Role of the Medial Prefrontal ..                  0             0
# Jarcho et al-Developmental effects of decis..                  0             0
# John O Doherty-Dissociating Valence of Outcom..                0             1
# Koeneke et al-Individual preferences modulat..                 0             0
# Lawrence et al-Distinct Roles of Prefrontal C..                0             0
# Nieuwenhuis et al-Activity in human reward-sensi..             0             2
# Schonberg et al-Decreasing ventromedial prefro..               0             1
# Sescousse et al-The Architecture of Reward Val..               0             2
# Smith et al-Distinct Value Signals in Ante..                   0             2
# Vassena et al-Dissociating contributions of ..                 0             4
# Winston et al-Brain systems for assessing fa..                 2             0
# Xue et al-Functional Dissociations of Ri..                     0             4
# select11_reward_decision-making_anticipation
# 100%|██████████| 7/7 [00:00<00:00, 83.26it/s]
# (8, 3)
#                                                               1           2  \
# Cluster ID
# Center of Mass                                      (0, 26, 41)  (-9, 6, 1)
# Abler et al-From uncertainty to reward - B..                  0           3
# Cohen et al-Individual differences in extr..                  0           0
# Jarcho et al-Developmental effects of decis..                 1           1
# Koeneke et al-Individual preferences modulat..                0           0
# Rosell-Negre et al-Monetary reward magnitude ef...            0           1
# Smith et al-Neural substrates of reward ma..                  2           0
# Tobler et al-Reward Value Coding Distinct F..                 0           3
#
#                                                                   3
# Cluster ID
# Center of Mass                                      (-19, -14, -15)
# Abler et al-From uncertainty to reward - B..                      1
# Cohen et al-Individual differences in extr..                      0
# Jarcho et al-Developmental effects of decis..                     0
# Koeneke et al-Individual preferences modulat..                    0
# Rosell-Negre et al-Monetary reward magnitude ef...                0
# Smith et al-Neural substrates of reward ma..                      2
# Tobler et al-Reward Value Coding Distinct F..                     1
# select12_reward_decision-making_decision
# 100%|██████████| 4/4 [00:00<00:00, 71.36it/s]
# (5, 4)
#                                                             1             2  \
# Cluster ID
# Center of Mass                                    (32, 24, 1)  (29, -93, 0)
# Lawrence et al-Distinct Roles of Prefrontal C..             0             0
# Rogers et al-Distinct Portions of Anterior ..               1             0
# Schonberg et al-Decreasing ventromedial prefro..            1             1
# Vassena et al-Dissociating contributions of ..              1             1
#
#                                                             3               4
# Cluster ID
# Center of Mass                                    (7, 27, 30)  (-27, -91, -4)
# Lawrence et al-Distinct Roles of Prefrontal C..             0               0
# Rogers et al-Distinct Portions of Anterior ..               0               0
# Schonberg et al-Decreasing ventromedial prefro..            1               2
# Vassena et al-Dissociating contributions of ..              1               1

# %% [markdown]
# ## Conjunctions

# %%
import copy
from nilearn.image import math_img
import numpy as np

# %%
tmp_imgs = copy.deepcopy(imgs)

# %%
dict_keys = list(tmp_imgs.keys())
dict_keys
# Out:
# ['select00_test',
#  'select01_wm',
#  'select02_wm_decision-making',
#  'select03_reward_anticipation_rw-norw',
#  'select04_reward_anticipation_high_low_rew',
#  'select05_reward_anticipation_exp_recv_rew',
#  'select06_reward_outcome_rw-norw',
#  'select07_reward_outcome_risk-safe',
#  'select08_reward_outcome_high-low',
#  'select09_reward_outcome_win-lose',
#  'select10_reward_decision-making_outcome',
#  'select11_reward_decision-making_anticipation',
#  'select12_reward_decision-making_decision']

# %%
# %%time
formula = "np.where(img1 * img2 > 0, np.minimum(img1, img2), 0)"
img_conj = math_img(formula, img1=copy.deepcopy(tmp_imgs[dict_keys[3]]), img2=copy.deepcopy(tmp_imgs[dict_keys[11]]))
num_vox = np.sum(img_conj.get_fdata() > 0)
num_vox
# Out:
# CPU times: total: 328 ms
# Wall time: 330 ms
# 59

# %% [markdown]
# TEST the conjunctions 3 vs 2x2
# //1,4,12
# //3 4 11

# %%
# %%time
formula = "np.where(img1 * img2 * img3 > 0, np.minimum(img1, img2,img3), 0)"
img_conj1 = math_img(formula,
                     img1=copy.deepcopy(tmp_imgs[dict_keys[1]]),
                     img2=copy.deepcopy(tmp_imgs[dict_keys[4]]),
                     img3=copy.deepcopy(tmp_imgs[dict_keys[12]]))
num_vox = np.sum(img_conj1.get_fdata() > 0)
num_vox
# Out:
# CPU times: total: 672 ms
# Wall time: 668 ms
# 16

# %%
# %%time
formula = "np.where(img1 * img2 > 0, np.minimum(img1, img2), 0)"
img_conj2 = math_img(formula,
                     img1=copy.deepcopy(img_conj1),
                     img2=copy.deepcopy(tmp_imgs[dict_keys[10]]))
num_vox = np.sum(img_conj2.get_fdata() > 0)
num_vox
# Out:
# CPU times: total: 328 ms
# Wall time: 336 ms
# 0

# %%
# %%time
formula = "np.where(img1 * img2 > 0, np.minimum(img1, img2), 0)"
img_conj3 = math_img(formula,
                     img1=copy.deepcopy(img_conj2),
                     img2=copy.deepcopy(tmp_imgs[dict_keys[8]]))
num_vox = np.sum(img_conj3.get_fdata() > 0)
num_vox
# Out:
# CPU times: total: 344 ms
# Wall time: 347 ms
# 0

# %% [markdown]
# ### Get non null pixels

# %%
t1_data = img_conj.get_fdata()
t1_data.shape
# Out:
# (91, 109, 91)

# %%
pts_lst = []
for i in range(t1_data.shape[0]):
    for j in range(t1_data.shape[1]):
        for k in range(t1_data.shape[2]):
            if t1_data[i, j, k] != 0: pts_lst.append([i, j, k])

# %%
len(pts_lst)
# Out:
# 59

# %% [markdown]
# ## Save img to nifti

# %%
img_to_save = img_conj1
img_name = 'img_combo1_4'
nib.save(img_to_save, os.path.join(os.path.abspath(_nii_combos_folder), img_name + '.nii'))

# %% [markdown]
# ## recursive conjunctions

# %%
# Create a base nifti
base_img = math_img("np.where(img1  > 0, 10000,10000)", img1=copy.deepcopy(tmp_imgs[dict_keys[0]]))

# %%
### !! Check for empty maps
rec_list = ['base_img',
            'select01_wm',
            'select02_wm_decision-making',
            'select03_reward_anticipation_rw-norw',
            'select04_reward_anticipation_high_low_rew',
            'select05_reward_anticipation_exp_recv_rew',
            'select06_reward_outcome_rw-norw',
            'select07_reward_outcome_risk-safe', # Empty
            'select08_reward_outcome_high-low',
            'select09_reward_outcome_win-lose',
            'select10_reward_decision-making_outcome',
            'select11_reward_decision-making_anticipation',
            'select12_reward_decision-making_decision']

# %%
path_set = set()
tmp_imgs['base_img'] = base_img

# %%
formula = "np.where(img1 * img2 > 0, np.minimum(img1, img2), 0)"

def recursive_conjunction(index, img_conj, path):
    if index == len(rec_list): return
    img_conj = math_img(formula, img1=copy.deepcopy(img_conj), img2=copy.deepcopy(tmp_imgs[rec_list[index]]))
    if np.sum(img_conj.get_fdata() > 0):
        path_set.add(tuple(path))
    else:
        return
    print(tuple(path))
    for i in range(index + 1, len(rec_list) + 1):
        recursive_conjunction(i, copy.deepcopy(img_conj), path + [i])
    return

# %%
recursive_conjunction(0, base_img, [])
# Out:
# ()
# (1,)
# (1, 2)
# (1, 3)
# (1, 4)
# (1, 4, 10)
# (1, 4, 10, 12)
# (1, 4, 12)
# (1, 5)
# (1, 10)
# (1, 10, 12)
# (1, 11)
# (1, 12)
# (2,)
# (3,)
# (3, 4)
# (3, 4, 9)
# (3, 4, 9, 10)
# (3, 4, 10)
# (3, 4, 10, 11)
# (3, 4, 11)
# (3, 4, 12)
# (3, 9)
# (3, 9, 10)
# (3, 10)
# (3, 10, 11)
# (3, 11)
# (3, 12)
# (4,)
# (4, 9)
# (4, 9, 10)
# (4, 10)
# (4, 10, 11)
# (4, 10, 12)
# (4, 11)
# (4, 12)
# (5,)
# (6,)
# (6, 10)
# (8,)
# (8, 9)
# (9,)
# (9, 10)
# (10,)
# (10, 11)
# (10, 12)
# (11,)
# (12,)

# %%
print(path_set)
# Out:
# {(3, 9, 10), (2,), (3, 4), (5,), (4, 9), (4, 9, 10), (11,), (4, 10, 11), (4, 12), (3, 10), (8,), (8, 9), (3, 10, 11), (1, 10, 12), (3, 4, 9, 10), (1, 3), (10, 12), (1, 12), (3, 4, 10), (3, 4, 10, 11), (4,), (1,), (3, 9), (10,), (3, 12), (4, 11), (9, 10), (1, 2), (10, 11), (1, 5), (1, 11), (3, 4, 9), (1, 4, 10), (1, 4, 10, 12), (3, 4, 12), (6, 10), (3,), (9,), (3, 11), (6,), (4, 10), (12,), (4, 10, 12), (1, 4), (3, 4, 11), (1, 4, 12), (1, 10), ()}

# %% [markdown]
# ## Save models to pickle

# %%
import pickle
import csv

# %%
path_set_file_name = r'path_set.dump'
pickle.dump(path_set, open(os.path.join(os.path.abspath(_res_folder), path_set_file_name), 'wb'))

# %% [markdown]
# ## Load models from pickle

# %%
retrieved_path_set = pickle.load(open(os.path.join(os.path.abspath(_res_folder), path_set_file_name), 'rb'))
retrieved_path_set
# Out:
# {(),
#  (1,),
#  (1, 2),
#  (1, 3),
#  (1, 4),
#  (1, 4, 10),
#  (1, 4, 10, 12),
#  (1, 4, 12),
#  (1, 5),
#  (1, 10),
#  (1, 10, 12),
#  (1, 11),
#  (1, 12),
#  (2,),
#  (3,),
#  (3, 4),
#  (3, 4, 9),
#  (3, 4, 9, 10),
#  (3, 4, 10),
#  (3, 4, 10, 11),
#  (3, 4, 11),
#  (3, 4, 12),
#  (3, 9),
#  (3, 9, 10),
#  (3, 10),
#  (3, 10, 11),
#  (3, 11),
#  (3, 12),
#  (4,),
#  (4, 9),
#  (4, 9, 10),
#  (4, 10),
#  (4, 10, 11),
#  (4, 10, 12),
#  (4, 11),
#  (4, 12),
#  (5,),
#  (6,),
#  (6, 10),
#  (8,),
#  (8, 9),
#  (9,),
#  (9, 10),
#  (10,),
#  (10, 11),
#  (10, 12),
#  (11,),
#  (12,)}

# %%
lst_models = list(retrieved_path_set)
lst_models.sort(key=lambda x: len(x) if type(x) is tuple else 1)
display(lst_models)
# Out:
# [(),
#  (2,),
#  (5,),
#  (11,),
#  (8,),
#  (4,),
#  (1,),
#  (10,),
#  (3,),
#  (9,),
#  (6,),
#  (12,),
#  (3, 4),
#  (4, 9),
#  (4, 12),
#  (3, 10),
#  (8, 9),
#  (10, 12),
#  (1, 3),
#  (1, 12),
#  (3, 9),
#  (3, 12),
#  (4, 11),
#  (9, 10),
#  (1, 2),
#  (10, 11),
#  (1, 5),
#  (1, 11),
#  (6, 10),
#  (3, 11),
#  (4, 10),
#  (1, 4),
#  (1, 10),
#  (3, 9, 10),
#  (4, 9, 10),
#  (4, 10, 11),
#  (3, 10, 11),
#  (1, 10, 12),
#  (3, 4, 10),
#  (3, 4, 9),
#  (1, 4, 10),
#  (3, 4, 12),
#  (4, 10, 12),
#  (3, 4, 11),
#  (1, 4, 12),
#  (3, 4, 9, 10),
#  (3, 4, 10, 11),
#  (1, 4, 10, 12)]

# %%
lst_file_name = r'path_list.dump'
pickle.dump(path_set, open(os.path.join(os.path.abspath(_res_folder), lst_file_name), 'wb'))
# writing the data into the file
lst_file_name_csv = r'path_list.csv'
with open(os.path.join(os.path.abspath(_res_folder), lst_file_name_csv), 'w', newline='') as f:
    write = csv.writer(f)
    write.writerows(lst_models)

# %% [markdown]
# ## Convert to BA

# %%
lst_models = [list(x) for x in lst_models]

# %% [markdown]
# ### Eliminate the singular models

# %%
lst_models = [x for x in lst_models if len(x)]# and len(x) >1]
lst_models
# Out:
# [[2],
#  [5],
#  [11],
#  [8],
#  [4],
#  [1],
#  [10],
#  [3],
#  [9],
#  [6],
#  [12],
#  [3, 4],
#  [4, 9],
#  [4, 12],
#  [3, 10],
#  [8, 9],
#  [10, 12],
#  [1, 3],
#  [1, 12],
#  [3, 9],
#  [3, 12],
#  [4, 11],
#  [9, 10],
#  [1, 2],
#  [10, 11],
#  [1, 5],
#  [1, 11],
#  [6, 10],
#  [3, 11],
#  [4, 10],
#  [1, 4],
#  [1, 10],
#  [3, 9, 10],
#  [4, 9, 10],
#  [4, 10, 11],
#  [3, 10, 11],
#  [1, 10, 12],
#  [3, 4, 10],
#  [3, 4, 9],
#  [1, 4, 10],
#  [3, 4, 12],
#  [4, 10, 12],
#  [3, 4, 11],
#  [1, 4, 12],
#  [3, 4, 9, 10],
#  [3, 4, 10, 11],
#  [1, 4, 10, 12]]

# %% [markdown]
# ### Create the Conjugate images

# %%
import tqdm

# %%
formula = "np.where(img1 * img2 > 0, np.minimum(img1, img2), 0)"
img_conjugates = []
for model in tqdm.tqdm(lst_models):
    if not model: continue
    img_conj = copy.deepcopy(base_img)
    for i in range(len(model)):
        img_conj = math_img(formula,
                            img1=copy.deepcopy(img_conj),
                            img2=copy.deepcopy(tmp_imgs[dict_keys[model[i]]]))
    # num_vox = np.sum(img_conj.get_fdata() > 0)
    img_conjugates.append(img_conj)
# Out:
# 100%|██████████| 47/47 [00:34<00:00,  1.35it/s]

# %% [markdown]
# ### Obtain non null coordinates

# %%
def get_non_null_nifti_val(nifti):
    pts_lst = []
    for i in range(nifti.get_fdata().shape[0]):
        for j in range(nifti.get_fdata().shape[1]):
            for k in range(nifti.get_fdata().shape[2]):
                if nifti.get_fdata()[i, j, k] != 0: pts_lst.append([i, j, k])
    return pts_lst

# %%
pts_list_conj = []
for img in tqdm.tqdm(img_conjugates):
    pts_list_conj.append(get_non_null_nifti_val(img))
# Out:
# 100%|██████████| 47/47 [00:30<00:00,  1.52it/s]

# %% [markdown]
# ### Convert the Coordinates

# %%
from scipy.interpolate import interp1d
import util.function_conv_mni as util_conv
import importlib

importlib.reload(util_conv)
# Out:
# <module 'util.function_conv_mni' from 'D:\\scul\\uaic-ub\\licenta\\code\\util\\function_conv_mni.py'>

# %%
#Interpolation
X = [[1, 91], [1, 109], [1, 91]]
Y = [[-90, 90], [-126, 90], [-72, 108]]
# test value
x_interp = interp1d(X[0], Y[0])
y_interp = interp1d(X[1], Y[1])
z_interp = interp1d(X[2], Y[2])

# %%
pts_list_conj_conv = []
for pts in pts_list_conj:
    pts_list_conj_conv.append([[x_interp(x).item(), y_interp(y).item(), z_interp(z).item()] for x, y, z in pts])

# %%
one_line_lst = []
table_lst = []
for pts in pts_list_conj_conv:
    one_line, table = util_conv.find_structure(pts)
    one_line_lst.append(one_line)
    table_lst.append(table)

# %%
# for i in range(len(one_line_lst[34])):
#     print(one_line_lst[34][i])

# %% [markdown]
# ### Parse the results

# %%
one_line_lst_parsed = []
for ind, results in enumerate(one_line_lst):
    set_lst = [set() for x in range(7)]
    set_lst[0] = (ind, lst_models[ind])
    for result in results:
        for index, el in enumerate(result.split("//")):
            if index == 0 or el.rstrip().lstrip() == 'undefined': continue
            set_lst[index].add(el)
    one_line_lst_parsed.append(set_lst)

# %%
one_line_lst_parsed
# Out:
# [[(0, [2]),
#   {' Left Cerebrum ', ' Right Cerebrum '},
#   {' Parietal Lobe '},
#   {' Inferior Parietal Lobule ',
#    ' Precuneus ',
#    ' Sub-Gyral ',
#    ' Superior Parietal Lobule '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 19 ', ' brodmann area 39 ', ' brodmann area 7 '},
#   {' Angular_L (aal)',
#    ' Occipital_Mid_L (aal)',
#    ' Parietal_Inf_L (aal)',
#    ' Parietal_Sup_L (aal)',
#    ' Parietal_Sup_R (aal)',
#    ' Precuneus_R (aal)'}],
#  [(1, [5]),
#   {' Right Cerebrum '},
#   {' Frontal Lobe '},
#   {' Inferior Frontal Gyrus ', ' Middle Frontal Gyrus ', ' Sub-Gyral '},
#   {' White Matter '},
#   set(),
#   {' Frontal_Inf_Tri_R (aal)', ' Insula_R (aal)'}],
#  [(2, [11]),
#   {' Inter-Hemispheric ',
#    ' Left Cerebrum ',
#    ' Right Brainstem ',
#    ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Midbrain ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Cingulate Gyrus ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle ',
#    ' Lentiform Nucleus ',
#    ' Medial Frontal Gyrus ',
#    ' Parahippocampa Gyrus ',
#    ' Third Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ',
#    ' Caudate Head ',
#    ' Lateral Globus Pallidus ',
#    ' Medial Globus Pallidus ',
#    ' Putamen ',
#    ' brodmann area 25 ',
#    ' brodmann area 28 ',
#    ' brodmann area 32 ',
#    ' brodmann area 34 ',
#    ' brodmann area 35 ',
#    ' brodmann area 6 '},
#   {' Caudate_R (aal)',
#    ' Cingulum_Mid_L (aal)',
#    ' Cingulum_Mid_R (aal)',
#    ' Frontal_Sup_Medial_L (aal)',
#    ' Hippocampus_R (aal)',
#    ' Pallidum_R (aal)',
#    ' ParaHippocampal_R (aal)'}],
#  [(3, [8]),
#   {' Inter-Hemispheric ', ' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Cingulate Gyrus ',
#    ' Extra-Nuclear ',
#    ' Posterior Cingulate ',
#    ' Sub-Gyral '},
#   {' Gray Matter ', ' White Matter '},
#   {' Corpus Callosum ',
#    ' brodmann area 23 ',
#    ' brodmann area 24 ',
#    ' brodmann area 31 ',
#    ' brodmann area 32 '},
#   {' Cingulum_Ant_L (aal)',
#    ' Cingulum_Ant_R (aal)',
#    ' Cingulum_Mid_R (aal)',
#    ' Cingulum_Post_L (aal)'}],
#  [(4, [4]),
#   {' Inter-Hemispheric ',
#    ' Left Cerebrum ',
#    ' Right Brainstem ',
#    ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Midbrain ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Cingulate Gyrus ',
#    ' Claustrum ',
#    ' Extra-Nuclear ',
#    ' Inferior Frontal Gyrus ',
#    ' Insula ',
#    ' Lateral Ventricle ',
#    ' Lentiform Nucleus ',
#    ' Parahippocampa Gyrus ',
#    ' Sub-Gyral ',
#    ' Subcallosal Gyrus ',
#    ' Thalamus '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ',
#    ' Caudate Head ',
#    ' Corpus Callosum ',
#    ' Hypothalamus ',
#    ' Lateral Globus Pallidus ',
#    ' Medial Globus Pallidus ',
#    ' Putamen ',
#    ' brodmann area 13 ',
#    ' brodmann area 24 ',
#    ' brodmann area 25 ',
#    ' brodmann area 28 ',
#    ' brodmann area 32 ',
#    ' brodmann area 33 ',
#    ' brodmann area 34 ',
#    ' brodmann area 35 ',
#    ' brodmann area 47 '},
#   {' Caudate_L (aal)',
#    ' Caudate_R (aal)',
#    ' Cingulum_Ant_L (aal)',
#    ' Cingulum_Ant_R (aal)',
#    ' Cingulum_Mid_L (aal)',
#    ' Frontal_Inf_Orb_L (aal)',
#    ' Frontal_Sup_Medial_L (aal)',
#    ' Frontal_Sup_Orb_L (aal)',
#    ' Hippocampus_R (aal)',
#    ' Insula_L (aal)',
#    ' Insula_R (aal)',
#    ' Olfactory_L (aal)',
#    ' Olfactory_R (aal)',
#    ' Pallidum_L (aal)',
#    ' Pallidum_R (aal)',
#    ' ParaHippocampal_R (aal)',
#    ' Putamen_L (aal)',
#    ' Putamen_R (aal)',
#    ' Rectus_L (aal)',
#    ' Rectus_R (aal)'}],
#  [(5, [1]),
#   {' Inter-Hemispheric ', ' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Parietal Lobe ', ' Sub-lobar '},
#   {' Angular Gyrus ',
#    ' Cingulate Gyrus ',
#    ' Claustrum ',
#    ' Extra-Nuclear ',
#    ' Inferior Frontal Gyrus ',
#    ' Inferior Parietal Lobule ',
#    ' Insula ',
#    ' Lentiform Nucleus ',
#    ' Medial Frontal Gyrus ',
#    ' Middle Frontal Gyrus ',
#    ' Precentral Gyrus ',
#    ' Precuneus ',
#    ' Sub-Gyral ',
#    ' Superior Frontal Gyrus ',
#    ' Superior Parietal Lobule ',
#    ' Supramarginal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' Putamen ',
#    ' brodmann area 10 ',
#    ' brodmann area 13 ',
#    ' brodmann area 19 ',
#    ' brodmann area 32 ',
#    ' brodmann area 39 ',
#    ' brodmann area 40 ',
#    ' brodmann area 46 ',
#    ' brodmann area 47 ',
#    ' brodmann area 6 ',
#    ' brodmann area 7 ',
#    ' brodmann area 8 ',
#    ' brodmann area 9 '},
#   {' Angular_L (aal)',
#    ' Angular_R (aal)',
#    ' Cingulum_Mid_L (aal)',
#    ' Cingulum_Mid_R (aal)',
#    ' Cuneus_R (aal)',
#    ' Frontal_Inf_Oper_R (aal)',
#    ' Frontal_Inf_Orb_L (aal)',
#    ' Frontal_Inf_Orb_R (aal)',
#    ' Frontal_Inf_Tri_L (aal)',
#    ' Frontal_Inf_Tri_R (aal)',
#    ' Frontal_Mid_L (aal)',
#    ' Frontal_Mid_Orb_R (aal)',
#    ' Frontal_Mid_R (aal)',
#    ' Frontal_Sup_L (aal)',
#    ' Frontal_Sup_Medial_L (aal)',
#    ' Frontal_Sup_Medial_R (aal)',
#    ' Frontal_Sup_R (aal)',
#    ' Insula_L (aal)',
#    ' Insula_R (aal)',
#    ' Occipital_Mid_R (aal)',
#    ' Occipital_Sup_R (aal)',
#    ' Parietal_Inf_L (aal)',
#    ' Parietal_Inf_R (aal)',
#    ' Parietal_Sup_L (aal)',
#    ' Parietal_Sup_R (aal)',
#    ' Precentral_L (aal)',
#    ' Precentral_R (aal)',
#    ' Precuneus_R (aal)',
#    ' Putamen_R (aal)',
#    ' Supp_Motor_Area_L (aal)',
#    ' Supp_Motor_Area_R (aal)'}],
#  [(6, [10]),
#   {' Inter-Hemispheric ', ' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Claustrum ',
#    ' Extra-Nuclear ',
#    ' Inferior Frontal Gyrus ',
#    ' Insula ',
#    ' Lateral Ventricle ',
#    ' Lentiform Nucleus ',
#    ' Medial Frontal Gyrus ',
#    ' Parahippocampa Gyrus ',
#    ' Sub-Gyral ',
#    ' Subcallosal Gyrus ',
#    ' Superior Frontal Gyrus '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Amygdala ',
#    ' Anterior Commissure ',
#    ' Caudate Head ',
#    ' Lateral Globus Pallidus ',
#    ' Medial Globus Pallidus ',
#    ' Putamen ',
#    ' brodmann area 10 ',
#    ' brodmann area 11 ',
#    ' brodmann area 13 ',
#    ' brodmann area 25 ',
#    ' brodmann area 32 ',
#    ' brodmann area 34 ',
#    ' brodmann area 45 ',
#    ' brodmann area 47 '},
#   {' Amygdala_L (aal)',
#    ' Amygdala_R (aal)',
#    ' Caudate_L (aal)',
#    ' Caudate_R (aal)',
#    ' Cingulum_Ant_L (aal)',
#    ' Cingulum_Ant_R (aal)',
#    ' Frontal_Inf_Orb_L (aal)',
#    ' Frontal_Inf_Tri_L (aal)',
#    ' Frontal_Med_Orb_L (aal)',
#    ' Frontal_Med_Orb_R (aal)',
#    ' Frontal_Sup_Medial_L (aal)',
#    ' Frontal_Sup_Medial_R (aal)',
#    ' Hippocampus_R (aal)',
#    ' Insula_L (aal)',
#    ' Olfactory_L (aal)',
#    ' Olfactory_R (aal)',
#    ' Pallidum_L (aal)',
#    ' Pallidum_R (aal)',
#    ' ParaHippocampal_R (aal)',
#    ' Putamen_L (aal)',
#    ' Putamen_R (aal)',
#    ' Rectus_L (aal)',
#    ' Rectus_R (aal)'}],
#  [(7, [3]),
#   {' Inter-Hemispheric ',
#    ' Left Brainstem ',
#    ' Left Cerebrum ',
#    ' Right Cerebrum '},
#   {' Frontal Lobe ',
#    ' Limbic Lobe ',
#    ' Midbrain ',
#    ' Sub-lobar ',
#    ' Temporal Lobe '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Cingulate Gyrus ',
#    ' Extra-Nuclear ',
#    ' Inferior Frontal Gyrus ',
#    ' Insula ',
#    ' Lateral Ventricle ',
#    ' Lentiform Nucleus ',
#    ' Medial Frontal Gyrus ',
#    ' Parahippocampa Gyrus ',
#    ' Sub-Gyral ',
#    ' Subcallosal Gyrus ',
#    ' Superior Temporal Gyrus ',
#    ' Thalamus ',
#    ' Third Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ',
#    ' Caudate Head ',
#    ' Hypothalamus ',
#    ' Lateral Globus Pallidus ',
#    ' Medial Dorsal Nucleus ',
#    ' Medial Globus Pallidus ',
#    ' Putamen ',
#    ' Ventral Anterior Nucleus ',
#    ' Ventral Lateral Nucleus ',
#    ' brodmann area 13 ',
#    ' brodmann area 24 ',
#    ' brodmann area 25 ',
#    ' brodmann area 32 ',
#    ' brodmann area 34 ',
#    ' brodmann area 38 ',
#    ' brodmann area 47 '},
#   {' Amygdala_R (aal)',
#    ' Caudate_L (aal)',
#    ' Caudate_R (aal)',
#    ' Cingulum_Ant_L (aal)',
#    ' Cingulum_Mid_L (aal)',
#    ' Frontal_Inf_Orb_L (aal)',
#    ' Frontal_Sup_Medial_L (aal)',
#    ' Frontal_Sup_Orb_L (aal)',
#    ' Insula_L (aal)',
#    ' Olfactory_L (aal)',
#    ' Olfactory_R (aal)',
#    ' Pallidum_L (aal)',
#    ' Pallidum_R (aal)',
#    ' Putamen_L (aal)',
#    ' Putamen_R (aal)',
#    ' Rectus_L (aal)',
#    ' Supp_Motor_Area_L (aal)',
#    ' Temporal_Pole_Sup_L (aal)',
#    ' Thalamus_L (aal)'}],
#  [(8, [9]),
#   {' Inter-Hemispheric ', ' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Parietal Lobe ', ' Sub-lobar '},
#   {' Angular Gyrus ',
#    ' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Inferior Parietal Lobule ',
#    ' Lentiform Nucleus ',
#    ' Precuneus ',
#    ' Sub-Gyral ',
#    ' Subcallosal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' Caudate Head ',
#    ' Corpus Callosum ',
#    ' Lateral Globus Pallidus ',
#    ' Putamen ',
#    ' brodmann area 13 ',
#    ' brodmann area 24 ',
#    ' brodmann area 32 ',
#    ' brodmann area 39 ',
#    ' brodmann area 40 '},
#   {' Angular_L (aal)',
#    ' Caudate_L (aal)',
#    ' Cingulum_Ant_L (aal)',
#    ' Cingulum_Ant_R (aal)',
#    ' Frontal_Sup_Orb_L (aal)',
#    ' Occipital_Mid_L (aal)',
#    ' Olfactory_L (aal)',
#    ' Pallidum_L (aal)',
#    ' Parietal_Inf_L (aal)',
#    ' Putamen_L (aal)',
#    ' Rectus_L (aal)'}],
#  [(9, [6]),
#   {' Inter-Hemispheric ',
#    ' Left Brainstem ',
#    ' Left Cerebrum ',
#    ' Right Brainstem ',
#    ' Right Cerebrum '},
#   {' Frontal Lobe ',
#    ' Limbic Lobe ',
#    ' Midbrain ',
#    ' Pons ',
#    ' Sub-lobar ',
#    ' Temporal Lobe '},
#   {' Anterior Cingulate ',
#    ' Inferior Frontal Gyrus ',
#    ' Lateral Ventricle ',
#    ' Medial Frontal Gyrus ',
#    ' Parahippocampa Gyrus ',
#    ' Sub-Gyral ',
#    ' Superior Temporal Gyrus ',
#    ' Uncus '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Amygdala ',
#    ' Hippocampus ',
#    ' brodmann area 10 ',
#    ' brodmann area 11 ',
#    ' brodmann area 32 ',
#    ' brodmann area 47 '},
#   {' Amygdala_L (aal)',
#    ' Cingulum_Ant_L (aal)',
#    ' Frontal_Inf_Orb_L (aal)',
#    ' Frontal_Med_Orb_L (aal)',
#    ' Frontal_Med_Orb_R (aal)',
#    ' Fusiform_L (aal)',
#    ' Hippocampus_L (aal)',
#    ' Insula_L (aal)',
#    ' ParaHippocampal_L (aal)',
#    ' Temporal_Pole_Sup_L (aal)'}],
#  [(10, [12]),
#   {' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Occipital Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Cingulate Gyrus ',
#    ' Cuneus ',
#    ' Extra-Nuclear ',
#    ' Inferior Frontal Gyrus ',
#    ' Inferior Occipital Gyrus ',
#    ' Insula ',
#    ' Lingual Gyrus ',
#    ' Middle Occipital Gyrus ',
#    ' Sub-Gyral '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 13 ',
#    ' brodmann area 18 ',
#    ' brodmann area 19 ',
#    ' brodmann area 24 ',
#    ' brodmann area 32 ',
#    ' brodmann area 47 '},
#   {' Calcarine_R (aal)',
#    ' Cingulum_Ant_L (aal)',
#    ' Cingulum_Mid_L (aal)',
#    ' Frontal_Inf_Orb_L (aal)',
#    ' Frontal_Inf_Tri_L (aal)',
#    ' Frontal_Sup_Medial_L (aal)',
#    ' Fusiform_R (aal)',
#    ' Insula_L (aal)',
#    ' Lingual_R (aal)',
#    ' Occipital_Inf_R (aal)',
#    ' Occipital_Mid_L (aal)'}],
#  [(11, [3, 4]),
#   {' Inter-Hemispheric ', ' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Cingulate Gyrus ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle ',
#    ' Lentiform Nucleus ',
#    ' Sub-Gyral ',
#    ' Subcallosal Gyrus '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ',
#    ' Caudate Head ',
#    ' Hypothalamus ',
#    ' Lateral Globus Pallidus ',
#    ' Medial Globus Pallidus ',
#    ' Putamen ',
#    ' brodmann area 13 ',
#    ' brodmann area 25 ',
#    ' brodmann area 32 ',
#    ' brodmann area 47 '},
#   {' Caudate_L (aal)',
#    ' Caudate_R (aal)',
#    ' Cingulum_Ant_L (aal)',
#    ' Cingulum_Mid_L (aal)',
#    ' Frontal_Sup_Orb_L (aal)',
#    ' Olfactory_L (aal)',
#    ' Olfactory_R (aal)',
#    ' Pallidum_L (aal)',
#    ' Pallidum_R (aal)',
#    ' Putamen_L (aal)',
#    ' Putamen_R (aal)',
#    ' Rectus_L (aal)'}],
#  [(12, [4, 9]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Extra-Nuclear ', ' Lentiform Nucleus ', ' Subcallosal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' Lateral Globus Pallidus ', ' Putamen ', ' brodmann area 13 '},
#   {' Caudate_L (aal)',
#    ' Olfactory_L (aal)',
#    ' Pallidum_L (aal)',
#    ' Putamen_L (aal)',
#    ' Rectus_L (aal)'}],
#  [(13, [4, 12]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Cingulate Gyrus ',
#    ' Extra-Nuclear ',
#    ' Inferior Frontal Gyrus ',
#    ' Insula '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 24 ', ' brodmann area 32 ', ' brodmann area 47 '},
#   {' Cingulum_Ant_L (aal)', ' Cingulum_Mid_L (aal)', ' Insula_L (aal)'}],
#  [(14, [3, 10]),
#   {' Inter-Hemispheric ', ' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle ',
#    ' Lentiform Nucleus ',
#    ' Parahippocampa Gyrus ',
#    ' Subcallosal Gyrus '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ',
#    ' Caudate Head ',
#    ' Lateral Globus Pallidus ',
#    ' Putamen ',
#    ' brodmann area 13 ',
#    ' brodmann area 25 ',
#    ' brodmann area 34 '},
#   {' Amygdala_R (aal)',
#    ' Caudate_L (aal)',
#    ' Caudate_R (aal)',
#    ' Olfactory_L (aal)',
#    ' Olfactory_R (aal)',
#    ' Pallidum_L (aal)',
#    ' Pallidum_R (aal)',
#    ' Putamen_L (aal)',
#    ' Putamen_R (aal)',
#    ' Rectus_L (aal)'}],
#  [(15, [8, 9]),
#   {' Left Cerebrum '},
#   {' Limbic Lobe '},
#   {' Anterior Cingulate '},
#   {' Gray Matter '},
#   {' brodmann area 24 '},
#   {' Cingulum_Ant_L (aal)'}],
#  [(16, [10, 12]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Extra-Nuclear ', ' Inferior Frontal Gyrus ', ' Insula ', ' Sub-Gyral '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 13 ', ' brodmann area 47 '},
#   {' Frontal_Inf_Orb_L (aal)', ' Frontal_Inf_Tri_L (aal)', ' Insula_L (aal)'}],
#  [(17, [1, 3]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe '},
#   {' Cingulate Gyrus ', ' Inferior Frontal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 32 ', ' brodmann area 47 '},
#   {' Cingulum_Mid_L (aal)', ' Frontal_Inf_Orb_L (aal)', ' Insula_L (aal)'}],
#  [(18, [1, 12]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Extra-Nuclear ', ' Inferior Frontal Gyrus ', ' Insula ', ' Sub-Gyral '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 13 ', ' brodmann area 47 '},
#   {' Frontal_Inf_Orb_L (aal)', ' Frontal_Inf_Tri_L (aal)', ' Insula_L (aal)'}],
#  [(19, [3, 9]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Extra-Nuclear ', ' Lentiform Nucleus ', ' Subcallosal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' Lateral Globus Pallidus ', ' Putamen ', ' brodmann area 13 '},
#   {' Caudate_L (aal)',
#    ' Olfactory_L (aal)',
#    ' Pallidum_L (aal)',
#    ' Putamen_L (aal)',
#    ' Rectus_L (aal)'}],
#  [(20, [3, 12]),
#   {' Left Cerebrum '},
#   {' Limbic Lobe '},
#   {' Anterior Cingulate ', ' Cingulate Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 32 '},
#   {' Cingulum_Ant_L (aal)',
#    ' Cingulum_Mid_L (aal)',
#    ' Frontal_Sup_Medial_L (aal)'}],
#  [(21, [4, 11]),
#   {' Right Brainstem ', ' Right Cerebrum '},
#   {' Limbic Lobe ', ' Midbrain ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle ',
#    ' Lentiform Nucleus ',
#    ' Parahippocampa Gyrus '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ',
#    ' Caudate Head ',
#    ' Lateral Globus Pallidus ',
#    ' Medial Globus Pallidus ',
#    ' Putamen ',
#    ' brodmann area 25 ',
#    ' brodmann area 28 ',
#    ' brodmann area 34 ',
#    ' brodmann area 35 '},
#   {' Caudate_R (aal)',
#    ' Hippocampus_R (aal)',
#    ' Pallidum_R (aal)',
#    ' ParaHippocampal_R (aal)'}],
#  [(22, [9, 10]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Extra-Nuclear ', ' Lentiform Nucleus ', ' Subcallosal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' Lateral Globus Pallidus ', ' Putamen ', ' brodmann area 13 '},
#   {' Caudate_L (aal)',
#    ' Olfactory_L (aal)',
#    ' Pallidum_L (aal)',
#    ' Putamen_L (aal)',
#    ' Rectus_L (aal)'}],
#  [(23, [1, 2]),
#   {' Left Cerebrum '},
#   {' Parietal Lobe '},
#   {' Superior Parietal Lobule '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 7 '},
#   {' Parietal_Inf_L (aal)', ' Parietal_Sup_L (aal)'}],
#  [(24, [10, 11]),
#   {' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle ',
#    ' Lentiform Nucleus '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ',
#    ' Caudate Head ',
#    ' Medial Globus Pallidus ',
#    ' brodmann area 25 '},
#   {' Caudate_R (aal)'}],
#  [(25, [1, 5]),
#   {' Right Cerebrum '},
#   {' Frontal Lobe '},
#   {' Sub-Gyral '},
#   {' White Matter '},
#   set(),
#   set()],
#  [(26, [1, 11]),
#   {' Inter-Hemispheric ', ' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe '},
#   {' Cingulate Gyrus ', ' Medial Frontal Gyrus '},
#   {' Gray Matter '},
#   {' brodmann area 32 ', ' brodmann area 6 '},
#   {' Cingulum_Mid_L (aal)',
#    ' Cingulum_Mid_R (aal)',
#    ' Frontal_Sup_Medial_L (aal)'}],
#  [(27, [6, 10]),
#   {' Inter-Hemispheric ', ' Left Cerebrum '},
#   {' Frontal Lobe '},
#   {' Medial Frontal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 10 ', ' brodmann area 11 '},
#   {' Frontal_Med_Orb_L (aal)'}],
#  [(28, [3, 11]),
#   {' Inter-Hemispheric ', ' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ', ' Caudate Head ', ' brodmann area 25 '},
#   {' Caudate_R (aal)'}],
#  [(29, [4, 10]),
#   {' Inter-Hemispheric ', ' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Claustrum ',
#    ' Extra-Nuclear ',
#    ' Inferior Frontal Gyrus ',
#    ' Insula ',
#    ' Lateral Ventricle ',
#    ' Lentiform Nucleus ',
#    ' Subcallosal Gyrus '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ',
#    ' Caudate Head ',
#    ' Lateral Globus Pallidus ',
#    ' Medial Globus Pallidus ',
#    ' Putamen ',
#    ' brodmann area 13 ',
#    ' brodmann area 25 ',
#    ' brodmann area 47 '},
#   {' Caudate_L (aal)',
#    ' Caudate_R (aal)',
#    ' Frontal_Inf_Orb_L (aal)',
#    ' Insula_L (aal)',
#    ' Olfactory_L (aal)',
#    ' Olfactory_R (aal)',
#    ' Pallidum_L (aal)',
#    ' Pallidum_R (aal)',
#    ' Putamen_L (aal)',
#    ' Putamen_R (aal)',
#    ' Rectus_L (aal)',
#    ' Rectus_R (aal)'}],
#  [(30, [1, 4]),
#   {' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Claustrum ', ' Extra-Nuclear ', ' Inferior Frontal Gyrus ', ' Insula '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 13 ', ' brodmann area 47 '},
#   {' Frontal_Inf_Orb_L (aal)',
#    ' Insula_L (aal)',
#    ' Insula_R (aal)',
#    ' Putamen_R (aal)'}],
#  [(31, [1, 10]),
#   {' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Claustrum ',
#    ' Extra-Nuclear ',
#    ' Inferior Frontal Gyrus ',
#    ' Insula ',
#    ' Sub-Gyral '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 13 ', ' brodmann area 47 '},
#   {' Frontal_Inf_Orb_L (aal)',
#    ' Frontal_Inf_Tri_L (aal)',
#    ' Insula_L (aal)',
#    ' Putamen_R (aal)'}],
#  [(32, [3, 9, 10]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Extra-Nuclear ', ' Lentiform Nucleus ', ' Subcallosal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' Lateral Globus Pallidus ', ' Putamen ', ' brodmann area 13 '},
#   {' Caudate_L (aal)',
#    ' Olfactory_L (aal)',
#    ' Pallidum_L (aal)',
#    ' Putamen_L (aal)',
#    ' Rectus_L (aal)'}],
#  [(33, [4, 9, 10]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Extra-Nuclear ', ' Lentiform Nucleus ', ' Subcallosal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' Lateral Globus Pallidus ', ' Putamen ', ' brodmann area 13 '},
#   {' Caudate_L (aal)',
#    ' Olfactory_L (aal)',
#    ' Pallidum_L (aal)',
#    ' Putamen_L (aal)',
#    ' Rectus_L (aal)'}],
#  [(34, [4, 10, 11]),
#   {' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle ',
#    ' Lentiform Nucleus '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ',
#    ' Caudate Head ',
#    ' Medial Globus Pallidus ',
#    ' brodmann area 25 '},
#   {' Caudate_R (aal)'}],
#  [(35, [3, 10, 11]),
#   {' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ', ' Caudate Head ', ' brodmann area 25 '},
#   {' Caudate_R (aal)'}],
#  [(36, [1, 10, 12]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Extra-Nuclear ', ' Inferior Frontal Gyrus ', ' Insula ', ' Sub-Gyral '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 13 ', ' brodmann area 47 '},
#   {' Frontal_Inf_Orb_L (aal)', ' Frontal_Inf_Tri_L (aal)', ' Insula_L (aal)'}],
#  [(37, [3, 4, 10]),
#   {' Inter-Hemispheric ', ' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle ',
#    ' Lentiform Nucleus ',
#    ' Subcallosal Gyrus '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ',
#    ' Caudate Head ',
#    ' Lateral Globus Pallidus ',
#    ' Putamen ',
#    ' brodmann area 13 ',
#    ' brodmann area 25 '},
#   {' Caudate_L (aal)',
#    ' Caudate_R (aal)',
#    ' Olfactory_L (aal)',
#    ' Olfactory_R (aal)',
#    ' Pallidum_L (aal)',
#    ' Pallidum_R (aal)',
#    ' Putamen_L (aal)',
#    ' Putamen_R (aal)',
#    ' Rectus_L (aal)'}],
#  [(38, [3, 4, 9]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Extra-Nuclear ', ' Lentiform Nucleus ', ' Subcallosal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' Lateral Globus Pallidus ', ' Putamen ', ' brodmann area 13 '},
#   {' Caudate_L (aal)',
#    ' Olfactory_L (aal)',
#    ' Pallidum_L (aal)',
#    ' Putamen_L (aal)',
#    ' Rectus_L (aal)'}],
#  [(39, [1, 4, 10]),
#   {' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Claustrum ', ' Extra-Nuclear ', ' Inferior Frontal Gyrus ', ' Insula '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 13 ', ' brodmann area 47 '},
#   {' Frontal_Inf_Orb_L (aal)', ' Insula_L (aal)', ' Putamen_R (aal)'}],
#  [(40, [3, 4, 12]),
#   {' Left Cerebrum '},
#   {' Limbic Lobe '},
#   {' Anterior Cingulate ', ' Cingulate Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 32 '},
#   {' Cingulum_Ant_L (aal)', ' Cingulum_Mid_L (aal)'}],
#  [(41, [4, 10, 12]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Extra-Nuclear ', ' Inferior Frontal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 47 '},
#   {' Insula_L (aal)'}],
#  [(42, [3, 4, 11]),
#   {' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ', ' Caudate Head ', ' brodmann area 25 '},
#   {' Caudate_R (aal)'}],
#  [(43, [1, 4, 12]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Extra-Nuclear ', ' Inferior Frontal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 47 '},
#   {' Insula_L (aal)'}],
#  [(44, [3, 4, 9, 10]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Extra-Nuclear ', ' Lentiform Nucleus ', ' Subcallosal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' Lateral Globus Pallidus ', ' Putamen ', ' brodmann area 13 '},
#   {' Caudate_L (aal)',
#    ' Olfactory_L (aal)',
#    ' Pallidum_L (aal)',
#    ' Putamen_L (aal)',
#    ' Rectus_L (aal)'}],
#  [(45, [3, 4, 10, 11]),
#   {' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ', ' Caudate Head ', ' brodmann area 25 '},
#   {' Caudate_R (aal)'}],
#  [(46, [1, 4, 10, 12]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Extra-Nuclear ', ' Inferior Frontal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 47 '},
#   {' Insula_L (aal)'}]]

# %%
lst = [44,45,46]
for i in lst:
    print("\nCombo: ", lst_models[i])
    for index,el in enumerate(one_line_lst[i]):
        el_striped = el.split("//")
        if el_striped[5].rstrip().lstrip() != 'undefined':
            print(pts_list_conj_conv[i][index],el)
# Out:
# Combo:  [3, 4, 9, 10]
# [-20.0, 12.0, -10.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-18.0, 8.0, -8.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-18.0, 8.0, -6.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-18.0, 10.0, -10.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-18.0, 10.0, -8.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-18.0, 10.0, -6.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-18.0, 12.0, -10.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-18.0, 12.0, -8.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-18.0, 12.0, -6.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-18.0, 14.0, -12.0]  // Left Cerebrum // Frontal Lobe // Subcallosal Gyrus // Gray Matter // brodmann area 13 // undefined
# [-18.0, 14.0, -10.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-18.0, 14.0, -8.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-16.0, 8.0, -10.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-16.0, 8.0, -8.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-16.0, 8.0, -6.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-16.0, 8.0, -4.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-16.0, 10.0, -10.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-16.0, 10.0, -8.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-16.0, 10.0, -6.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-16.0, 10.0, -4.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-16.0, 12.0, -10.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-16.0, 12.0, -8.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-16.0, 12.0, -6.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-16.0, 14.0, -8.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-14.0, 8.0, -6.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-14.0, 8.0, -4.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Pallidum_L (aal)
# [-14.0, 10.0, -8.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-14.0, 10.0, -6.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-14.0, 12.0, -8.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-14.0, 12.0, -6.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
# [-12.0, 8.0, -6.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Lateral Globus Pallidus // Pallidum_L (aal)
# [-12.0, 8.0, -4.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Pallidum_L (aal)
# [-12.0, 10.0, -6.0]  // Left Cerebrum // Sub-lobar // Lentiform Nucleus // Gray Matter // Putamen // Putamen_L (aal)
#
# Combo:  [3, 4, 10, 11]
# [2.0, 2.0, -4.0]  // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 25 // undefined
# [2.0, 2.0, -2.0]  // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Anterior Commissure // undefined
# [4.0, 2.0, -2.0]  // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Anterior Commissure // undefined
# [4.0, 4.0, -6.0]  // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 25 // undefined
# [4.0, 4.0, -4.0]  // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 25 // undefined
# [4.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 2.0, -2.0]  // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Anterior Commissure // undefined
# [6.0, 4.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
#
# Combo:  [1, 4, 10, 12]
# [-36.0, 20.0, 0.0]  // Left Cerebrum // Sub-lobar // Extra-Nuclear // Gray Matter // brodmann area 47 // Insula_L (aal)
# [-34.0, 20.0, 0.0]  // Left Cerebrum // Sub-lobar // Extra-Nuclear // Gray Matter // brodmann area 47 // Insula_L (aal)
# [-32.0, 20.0, -2.0]  // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Insula_L (aal)

# %%
one_line_lst[46]
# Out:
# [' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // White Matter // undefined // Insula_L (aal)',
#  ' // Left Cerebrum // Sub-lobar // Extra-Nuclear // Gray Matter // brodmann area 47 // Insula_L (aal)',
#  ' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // White Matter // undefined // Insula_L (aal)',
#  ' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // White Matter // undefined // Insula_L (aal)',
#  ' // Left Cerebrum // Sub-lobar // Extra-Nuclear // Gray Matter // brodmann area 47 // Insula_L (aal)',
#  ' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // White Matter // undefined // Insula_L (aal)',
#  ' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // White Matter // undefined // Insula_L (aal)',
#  ' // Left Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // undefined // Insula_L (aal)',
#  ' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Insula_L (aal)',
#  ' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // White Matter // undefined // Insula_L (aal)',
#  ' // Left Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // undefined // Insula_L (aal)']

# %%
one_line_lst[46]
# Out:
# [' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // White Matter // undefined // Insula_L (aal)',
#  ' // Left Cerebrum // Sub-lobar // Extra-Nuclear // Gray Matter // brodmann area 47 // Insula_L (aal)',
#  ' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // White Matter // undefined // Insula_L (aal)',
#  ' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // White Matter // undefined // Insula_L (aal)',
#  ' // Left Cerebrum // Sub-lobar // Extra-Nuclear // Gray Matter // brodmann area 47 // Insula_L (aal)',
#  ' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // White Matter // undefined // Insula_L (aal)',
#  ' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // White Matter // undefined // Insula_L (aal)',
#  ' // Left Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // undefined // Insula_L (aal)',
#  ' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Insula_L (aal)',
#  ' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // White Matter // undefined // Insula_L (aal)',
#  ' // Left Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // undefined // Insula_L (aal)']
