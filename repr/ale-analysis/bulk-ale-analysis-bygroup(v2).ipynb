# %%
# %matplotlib inline

# %% [markdown]
# # ALE meta-analysis

# %%
import os
from os import listdir
from os.path import isfile, join
import nibabel as nib
from pathlib import Path

import matplotlib.pyplot as plt
from nilearn.plotting import plot_stat_map
from nimare.io import convert_sleuth_to_dataset
from nimare.utils import get_resource_path

from nimare.correct import FWECorrector
from nimare.meta.cbma import ALE
import pickle
import csv
# Out:
# ERROR:duecredit:Failed to import duecredit due to No module named 'duecredit'

# %%
_dset_folder = r'../data_db/dataset_ale/v2/'
_nii_folder = r'../data_db/nifti-ale/by_grp/'
_nii_folder_z = r'../data_db/nifti-ale/by_grp/z_nii/'
_res_folder = r'../data_db/res/by_grp/'
_nii_combos_folder = r'../data_db/nifti-ale/combos/by_grp'
_statistics_folder = r'../data_db/nifti-ale/statistics/by_grp/'
_threshold = 1.644854  # cluster-level p < .05, one-tailed
_save = False

# %% [markdown]
# ## ALE Working Memory: visual task stimulus and task modality n-task

# %%
dsetfiles = {Path(f).stem: f for f in listdir(_dset_folder) if isfile(join(_dset_folder, f))}

# %%
files = {k: os.path.join(os.path.abspath(_dset_folder), file_name) for k, file_name in dsetfiles.items()}
dsets = {k: convert_sleuth_to_dataset(f) for k, f in files.items()}

# %%
corrected_results = {}
# ale = ALE(null_method="montecarlo",n_iters=100,n_cores=8)
ale = ALE(null_method="approximate")
corr = FWECorrector(method="montecarlo", voxel_thresh=0.001, n_iters=100, n_cores=8)
for index, (k, dset) in enumerate(dsets.items()):
    result = ale.fit(dset)
    corrected_results[k] = corr.transform(result)
# Out:
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:06<00:00, 15.47it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:05<00:00, 17.00it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:04<00:00, 24.39it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:04<00:00, 21.28it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:05<00:00, 19.82it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:03<00:00, 28.79it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:05<00:00, 19.17it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:03<00:00, 27.50it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:04<00:00, 20.13it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:04<00:00, 22.46it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:11<00:00,  8.51it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:05<00:00, 17.16it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.
# INFO:nimare.correct:Using correction method implemented in Estimator: nimare.meta.cbma.ale.ALE.correct_fwe_montecarlo.
# 100%|██████████| 100/100 [00:04<00:00, 24.69it/s]
# INFO:nimare.meta.cbma.base:Using null distribution for voxel-level FWE correction.

# %%
## Check
map_name = "z_desc-size_level-cluster_corr-FWE_method-montecarlo"
imgs = {}
res_len = len(corrected_results)
fig, axes = plt.subplots(figsize=(12, res_len * 10), nrows=res_len)
for index, (k, corr_result) in enumerate(corrected_results.items()):
    imgs[k] = corr_result.get_map(
        map_name
    )

    plot_stat_map(
        imgs[k],
        cut_coords=4,
        display_mode="z",
        title="Semantic select " + str(index),
        threshold=_threshold,
        cmap="RdBu_r",
        vmax=4,
        axes=axes[index],
        figure=fig,
    )
# Out:
# C:\ProgramData\Anaconda3\envs\tfg-env\lib\site-packages\nilearn\plotting\img_plotting.py:300: FutureWarning: Default resolution of the MNI template will change from 2mm to 1mm in version 0.10.0
#   anat_img = load_mni152_template()
# C:\ProgramData\Anaconda3\envs\tfg-env\lib\site-packages\nilearn\plotting\displays\_slicers.py:383: UserWarning: empty mask
#   get_mask_bounds(new_img_like(img, not_mask, affine))

# %% [markdown]
# ## Save images to nifti

# %%
if _save:
    for index, (file_name, img) in enumerate(imgs.items()):
        nib.save(img, os.path.join(os.path.abspath(_nii_folder), file_name + '.nii'))
        nib.save(corrected_results[file_name].get_map('z'),
                 os.path.join(os.path.abspath(_nii_folder_z), file_name + '-z.nii'))
    print("Saved!\n")
# Out:
# Saved!
#
# Saved!
#
# Saved!
#
# Saved!
#
# Saved!
#
# Saved!
#
# Saved!
#
# Saved!
#
# Saved!
#
# Saved!
#
# Saved!
#
# Saved!
#
# Saved!

# %% [markdown]
# ## Statistics

# %%
from IPython.display import display
from nimare.diagnostics import FocusCounter

counter = FocusCounter(
    target_image="z_desc-size_level-cluster_corr-FWE_method-montecarlo",
    voxel_thresh=_threshold,
)
fcscnt_tables = {}
for index, (file_name, corr_res) in enumerate(corrected_results.items()):
    print(file_name)
    count_table, _ = counter.transform(corr_res)
    print(count_table.shape)
    fcscnt_tables[file_name] = count_table
    display(count_table)
# Out:
# select00_test
# C:\ProgramData\Anaconda3\envs\tfg-env\lib\site-packages\nilearn\_utils\param_validation.py:72: UserWarning: The given float value must not exceed 0.0. But, you have given threshold=1.644854
#   warnings.warn("The given float value must not exceed {0}. "
# WARNING:nimare.diagnostics:No clusters found
# (2, 0)
# Empty DataFrame
# Columns: []
# Index: [Center of Mass, Test test test-]
# select01_wm
# 100%|██████████| 20/20 [00:00<00:00, 43.06it/s]
# (21, 9)
#                                                                 1  \
# Cluster ID
# Center of Mass                                      (44, -46, 43)
# Beneventi et al-An fMRI study of working memor....              0
# Carrion et al-Frontal Hypoactivation on Func.. ...              1
# Carrion et al-Frontal Hypoactivation on Func.. ...              1
# Di et al-Anterior cingulate cortex diff.. Table...              0
# Di et al-Anterior cingulate cortex diff.. Table...              0
# Drobyshevsky et al-A Rapid fMRI Task Battery fo...              1
# Duggirala et al-Stimulus-dependent modulation ....              0
# Duggirala et al-Stimulus-dependent modulation ....              0
# Duggirala et al-Stimulus-dependent modulation ....              0
# Duggirala et al-Stimulus-dependent modulation ....              0
# Lee et al-Abnormal neural activity in pa.. Tabl...              0
# Padilla et al-Long-term brain effects of N-b.. ...              0
# Padilla et al-Long-term brain effects of N-b.. ...              1
# Pochon et al-The neural system that bridges.. T...              0
# Pochon et al-The neural system that bridges.. T...              0
# Rodger et al-Inhibit  switch  and update - .. T...              2
# Schmidt et al-No gender differences in brain.. ...              0
# Seo et al-Working Memory Impairment in F.. Tabl...              1
# Taylor et al-A functional neuroimaging stud.. T...              0
# Taylor et al-A functional neuroimaging stud.. T...              0
#
#                                                               2            3  \
# Cluster ID
# Center of Mass                                      (31, 4, 55)  (1, 20, 45)
# Beneventi et al-An fMRI study of working memor....            1            1
# Carrion et al-Frontal Hypoactivation on Func.. ...            1            0
# Carrion et al-Frontal Hypoactivation on Func.. ...            1            1
# Di et al-Anterior cingulate cortex diff.. Table...            0            0
# Di et al-Anterior cingulate cortex diff.. Table...            0            0
# Drobyshevsky et al-A Rapid fMRI Task Battery fo...            1            1
# Duggirala et al-Stimulus-dependent modulation ....            0            0
# Duggirala et al-Stimulus-dependent modulation ....            0            0
# Duggirala et al-Stimulus-dependent modulation ....            0            0
# Duggirala et al-Stimulus-dependent modulation ....            0            0
# Lee et al-Abnormal neural activity in pa.. Tabl...            0            3
# Padilla et al-Long-term brain effects of N-b.. ...            0            0
# Padilla et al-Long-term brain effects of N-b.. ...            1            2
# Pochon et al-The neural system that bridges.. T...            0            0
# Pochon et al-The neural system that bridges.. T...            0            0
# Rodger et al-Inhibit  switch  and update - .. T...            2            0
# Schmidt et al-No gender differences in brain.. ...            1            2
# Seo et al-Working Memory Impairment in F.. Tabl...            1            4
# Taylor et al-A functional neuroimaging stud.. T...            1            3
# Taylor et al-A functional neuroimaging stud.. T...            0            0
#
#                                                                  4  \
# Cluster ID
# Center of Mass                                      (-22, -66, 43)
# Beneventi et al-An fMRI study of working memor....               0
# Carrion et al-Frontal Hypoactivation on Func.. ...               1
# Carrion et al-Frontal Hypoactivation on Func.. ...               1
# Di et al-Anterior cingulate cortex diff.. Table...               1
# Di et al-Anterior cingulate cortex diff.. Table...               0
# Drobyshevsky et al-A Rapid fMRI Task Battery fo...               1
# Duggirala et al-Stimulus-dependent modulation ....               0
# Duggirala et al-Stimulus-dependent modulation ....               0
# Duggirala et al-Stimulus-dependent modulation ....               0
# Duggirala et al-Stimulus-dependent modulation ....               0
# Lee et al-Abnormal neural activity in pa.. Tabl...               1
# Padilla et al-Long-term brain effects of N-b.. ...               0
# Padilla et al-Long-term brain effects of N-b.. ...               0
# Pochon et al-The neural system that bridges.. T...               0
# Pochon et al-The neural system that bridges.. T...               0
# Rodger et al-Inhibit  switch  and update - .. T...               0
# Schmidt et al-No gender differences in brain.. ...               0
# Seo et al-Working Memory Impairment in F.. Tabl...               1
# Taylor et al-A functional neuroimaging stud.. T...               0
# Taylor et al-A functional neuroimaging stud.. T...               0
#
#                                                                5  \
# Cluster ID
# Center of Mass                                      (-26, 2, 54)
# Beneventi et al-An fMRI study of working memor....             0
# Carrion et al-Frontal Hypoactivation on Func.. ...             0
# Carrion et al-Frontal Hypoactivation on Func.. ...             2
# Di et al-Anterior cingulate cortex diff.. Table...             1
# Di et al-Anterior cingulate cortex diff.. Table...             0
# Drobyshevsky et al-A Rapid fMRI Task Battery fo...             1
# Duggirala et al-Stimulus-dependent modulation ....             0
# Duggirala et al-Stimulus-dependent modulation ....             0
# Duggirala et al-Stimulus-dependent modulation ....             0
# Duggirala et al-Stimulus-dependent modulation ....             0
# Lee et al-Abnormal neural activity in pa.. Tabl...             2
# Padilla et al-Long-term brain effects of N-b.. ...             1
# Padilla et al-Long-term brain effects of N-b.. ...             0
# Pochon et al-The neural system that bridges.. T...             0
# Pochon et al-The neural system that bridges.. T...             0
# Rodger et al-Inhibit  switch  and update - .. T...             0
# Schmidt et al-No gender differences in brain.. ...             1
# Seo et al-Working Memory Impairment in F.. Tabl...             0
# Taylor et al-A functional neuroimaging stud.. T...             2
# Taylor et al-A functional neuroimaging stud.. T...             0
#
#                                                                6  \
# Cluster ID
# Center of Mass                                      (-31, 22, 0)
# Beneventi et al-An fMRI study of working memor....             1
# Carrion et al-Frontal Hypoactivation on Func.. ...             1
# Carrion et al-Frontal Hypoactivation on Func.. ...             1
# Di et al-Anterior cingulate cortex diff.. Table...             1
# Di et al-Anterior cingulate cortex diff.. Table...             0
# Drobyshevsky et al-A Rapid fMRI Task Battery fo...             0
# Duggirala et al-Stimulus-dependent modulation ....             0
# Duggirala et al-Stimulus-dependent modulation ....             1
# Duggirala et al-Stimulus-dependent modulation ....             0
# Duggirala et al-Stimulus-dependent modulation ....             0
# Lee et al-Abnormal neural activity in pa.. Tabl...             1
# Padilla et al-Long-term brain effects of N-b.. ...             0
# Padilla et al-Long-term brain effects of N-b.. ...             0
# Pochon et al-The neural system that bridges.. T...             0
# Pochon et al-The neural system that bridges.. T...             0
# Rodger et al-Inhibit  switch  and update - .. T...             1
# Schmidt et al-No gender differences in brain.. ...             1
# Seo et al-Working Memory Impairment in F.. Tabl...             1
# Taylor et al-A functional neuroimaging stud.. T...             0
# Taylor et al-A functional neuroimaging stud.. T...             0
#
#                                                                  7  \
# Cluster ID
# Center of Mass                                      (-37, -52, 46)
# Beneventi et al-An fMRI study of working memor....               1
# Carrion et al-Frontal Hypoactivation on Func.. ...               2
# Carrion et al-Frontal Hypoactivation on Func.. ...               1
# Di et al-Anterior cingulate cortex diff.. Table...               0
# Di et al-Anterior cingulate cortex diff.. Table...               0
# Drobyshevsky et al-A Rapid fMRI Task Battery fo...               1
# Duggirala et al-Stimulus-dependent modulation ....               0
# Duggirala et al-Stimulus-dependent modulation ....               2
# Duggirala et al-Stimulus-dependent modulation ....               0
# Duggirala et al-Stimulus-dependent modulation ....               0
# Lee et al-Abnormal neural activity in pa.. Tabl...               2
# Padilla et al-Long-term brain effects of N-b.. ...               0
# Padilla et al-Long-term brain effects of N-b.. ...               1
# Pochon et al-The neural system that bridges.. T...               0
# Pochon et al-The neural system that bridges.. T...               0
# Rodger et al-Inhibit  switch  and update - .. T...               1
# Schmidt et al-No gender differences in brain.. ...               0
# Seo et al-Working Memory Impairment in F.. Tabl...               1
# Taylor et al-A functional neuroimaging stud.. T...               1
# Taylor et al-A functional neuroimaging stud.. T...               1
#
#                                                                8             9
# Cluster ID
# Center of Mass                                      (-37, 51, 5)  (-46, 6, 27)
# Beneventi et al-An fMRI study of working memor....             0             1
# Carrion et al-Frontal Hypoactivation on Func.. ...             1             1
# Carrion et al-Frontal Hypoactivation on Func.. ...             1             1
# Di et al-Anterior cingulate cortex diff.. Table...             2             1
# Di et al-Anterior cingulate cortex diff.. Table...             0             0
# Drobyshevsky et al-A Rapid fMRI Task Battery fo...             1             0
# Duggirala et al-Stimulus-dependent modulation ....             0             0
# Duggirala et al-Stimulus-dependent modulation ....             0             1
# Duggirala et al-Stimulus-dependent modulation ....             0             0
# Duggirala et al-Stimulus-dependent modulation ....             0             0
# Lee et al-Abnormal neural activity in pa.. Tabl...             2             1
# Padilla et al-Long-term brain effects of N-b.. ...             0             0
# Padilla et al-Long-term brain effects of N-b.. ...             1             0
# Pochon et al-The neural system that bridges.. T...             0             0
# Pochon et al-The neural system that bridges.. T...             0             0
# Rodger et al-Inhibit  switch  and update - .. T...             1             0
# Schmidt et al-No gender differences in brain.. ...             0             0
# Seo et al-Working Memory Impairment in F.. Tabl...             0             1
# Taylor et al-A functional neuroimaging stud.. T...             1             0
# Taylor et al-A functional neuroimaging stud.. T...             1             0
# select02_wm_decision-making
# C:\ProgramData\Anaconda3\envs\tfg-env\lib\site-packages\nilearn\_utils\param_validation.py:72: UserWarning: The given float value must not exceed 1.5547735945968535. But, you have given threshold=1.644854
#   warnings.warn("The given float value must not exceed {0}. "
# WARNING:nimare.diagnostics:No clusters found
# (8, 0)
# Empty DataFrame
# Columns: []
# Index: [Center of Mass, Cruz et al-Alterations in the functional .. Table 3 - Summary of regions in the four-choice reversal learning task showing significant activation at reversal compared to expected positive reinforcement for ASD and controls, Nobre et al-Orienting Attention to Locatio.. Table 1 - Common Brain Activations to Precues and Retrocues, Nobre et al-Orienting Attention to Locatio.. Table 2-1 Differential Brain Activations to Precues and Retrocues, Nobre et al-Orienting Attention to Locatio.. Table 2-2 Differential Brain Activations to Precues and Retrocues, Reilhac et al-Role of the superior parietal .. Table 2-1 Cerebral regions activated during the letter string comparis on task for the substitution condition relative to baseline - Frame Dif - frames with strings from different families, Reilhac et al-Role of the superior parietal .. Table 2-1 Cerebral regions activated during the letter string comparis on task for the substitution condition relative to baseline - Sub Dif - string difference, Reilhac et al-Role of the superior parietal .. Table 2-1 Cerebral regions activated during the letter string comparis on task for the substitution condition relative to baseline - Sub Id - identical strings]
# select03_reward_anticipation_rw-norw
# 100%|██████████| 10/10 [00:00<00:00, 62.83it/s]
# (11, 5)
#                                                                1            2  \
# Cluster ID
# Center of Mass                                      (40, 20, -7)  (16, 9, -5)
# Cohen et al-Individual differences in extr.. Ta...             1            0
# John O Doherty et al-Neural Responses during An...             0            0
# Kirscg et al-Anticipation of reward in a no.. T...             1            2
# Kirscg et al-Anticipation of reward in a no.. T...             1            2
# Knutson et al-A region of mesial prefrontal .. ...             1            2
# Knutson et al-Anticipation of Increasing Mon.. ...             0            1
# Knutson et al-Dissociation of reward anticip.. ...             1            2
# Koeneke et al-Individual preferences modulat.. ...             1            0
# Spreckelmeyer et al-Anticipation of monetary an...             0            0
# Spreckelmeyer et al-Anticipation of monetary an...             0            0
#
#                                                              3            4  \
# Cluster ID
# Center of Mass                                      (5, -5, 4)  (6, 22, 35)
# Cohen et al-Individual differences in extr.. Ta...           1            0
# John O Doherty et al-Neural Responses during An...           0            0
# Kirscg et al-Anticipation of reward in a no.. T...           0            1
# Kirscg et al-Anticipation of reward in a no.. T...           1            0
# Knutson et al-A region of mesial prefrontal .. ...           1            1
# Knutson et al-Anticipation of Increasing Mon.. ...           1            2
# Knutson et al-Dissociation of reward anticip.. ...           1            1
# Koeneke et al-Individual preferences modulat.. ...           0            0
# Spreckelmeyer et al-Anticipation of monetary an...           0            0
# Spreckelmeyer et al-Anticipation of monetary an...           0            0
#
#                                                               5
# Cluster ID
# Center of Mass                                      (-7, 7, -4)
# Cohen et al-Individual differences in extr.. Ta...            0
# John O Doherty et al-Neural Responses during An...            0
# Kirscg et al-Anticipation of reward in a no.. T...            1
# Kirscg et al-Anticipation of reward in a no.. T...            0
# Knutson et al-A region of mesial prefrontal .. ...            2
# Knutson et al-Anticipation of Increasing Mon.. ...            1
# Knutson et al-Dissociation of reward anticip.. ...            2
# Koeneke et al-Individual preferences modulat.. ...            0
# Spreckelmeyer et al-Anticipation of monetary an...            0
# Spreckelmeyer et al-Anticipation of monetary an...            0
# select04_reward_anticipation_high_low_rew
# 100%|██████████| 13/13 [00:00<00:00, 79.19it/s]
# (14, 3)
#                                                              1             2  \
# Cluster ID
# Center of Mass                                      (10, 3, 1)  (11, 16, -9)
# Abler et al-From uncertainty to reward - B.. Ta...           1             0
# Abler et al-From uncertainty to reward - B.. Ta...           0             0
# Abler et al-From uncertainty to reward - B.. Ta...           0             0
# Croxson et al-Effort-Based Cost Benefit Valu.. ...           0             1
# Jarcho et al-Developmental effects of decis.. T...           0             0
# Jarcho et al-Developmental effects of decis.. T...           0             0
# Knutson et al-Anticipation of Increasing Mon.. ...           1             1
# Knutson et al-Distributed Neural Representat.. ...           0             0
# Knutson et al-Distributed Neural Representat.. ...           0             0
# Smith et al-Neural substrates of reward ma.. Ta...           0             0
# Spreckelmeyer et al-Anticipation of monetary an...           2             2
# Tobler et al-Reward Value Coding Distinct F.. T...           0             0
# Tobler et al-Reward Value Coding Distinct F.. T...           0             0
#
#                                                                3
# Cluster ID
# Center of Mass                                      (-12, 9, -1)
# Abler et al-From uncertainty to reward - B.. Ta...             1
# Abler et al-From uncertainty to reward - B.. Ta...             1
# Abler et al-From uncertainty to reward - B.. Ta...             1
# Croxson et al-Effort-Based Cost Benefit Valu.. ...             1
# Jarcho et al-Developmental effects of decis.. T...             1
# Jarcho et al-Developmental effects of decis.. T...             0
# Knutson et al-Anticipation of Increasing Mon.. ...             2
# Knutson et al-Distributed Neural Representat.. ...             0
# Knutson et al-Distributed Neural Representat.. ...             0
# Smith et al-Neural substrates of reward ma.. Ta...             0
# Spreckelmeyer et al-Anticipation of monetary an...             7
# Tobler et al-Reward Value Coding Distinct F.. T...             1
# Tobler et al-Reward Value Coding Distinct F.. T...             0
# select05_reward_anticipation_exp_recv_rew
# 100%|██████████| 4/4 [00:00<00:00, 114.18it/s]
# (5, 1)
#                                                                 1
# Cluster ID
# Center of Mass                                      (31, -36, 21)
# John O Doherty et al-Neural Responses during An...              0
# Rademacher et al-Dissociation of neural network...              1
# Rademacher et al-Dissociation of neural network...              1
# Tobler et al-Reward Value Coding Distinct F.. T...              0
# select06_reward_outcome_rw-norw
# C:\ProgramData\Anaconda3\envs\tfg-env\lib\site-packages\nilearn\_utils\param_validation.py:72: UserWarning: The given float value must not exceed 0.6128129910166272. But, you have given threshold=1.644854
#   warnings.warn("The given float value must not exceed {0}. "
# WARNING:nimare.diagnostics:No clusters found
# (13, 0)
# Empty DataFrame
# Columns: []
# Index: [Center of Mass, Cohen et al-Individual differences in extr.. Table 1 Study 1 reward - no reward, Cohen et al-Individual differences in extr.. Table 1 Study 2 reward - no reward, Elliott et al-Differential Response Patterns.. Table 1 - Maximally activated voxels in areas in which significant evoked activity was related to reward level - All-or-nothing response to reward, Elliott et al-Instrumental responding for re.. Table 2 - Maximally activated voxels in areas where significant evoked activity was related to a main effect of reward, Elliott et al-Instrumental responding for re.. Table 3 - Maximally activated voxels in areas where there was a significant modulation of responses to reward by the requirement to make an instrumental response, John O Doherty et al-Neural Responses during Antici.. Table 2-1 Regions Responding following Receipt of Glucose and Salt Tastes, Knutson et al-A region of mesial prefrontal .. Table 1-3 - reward versus nonreward outcomes on MPFC - Outcome: Potential gain vs no outcome, Knutson et al-Dissociation of reward anticip.. Table 1-4 - Group maximum Z-scores and Talairach Coordinates of activation foci, Koeneke et al-Individual preferences modulat.. Table 3 - Clusters showing preference-dependent activation during the outcome phase, Schienle et al-Binge-Eating Disorder  Reward .. Table 2. Brain Activation While Viewing Food Pictures (Contrast: Food > Neutral) in Normal-Weight Healthy Control Subjects (C-NW), Sescousse et al-The Architecture of Reward Val.. Table S3 - Brain regions activated by both monetary and erotic reward outcomes, Smith et al-Distinct Value Signals in Ante.. Table S6 - Regions exhibiting sensitivity to social value - defined as increased activation to attractive faces (those from the 4-star category) compared to unattractive faces (those from the 1-star category).]
# select07_reward_outcome_risk-safe
# C:\ProgramData\Anaconda3\envs\tfg-env\lib\site-packages\nilearn\_utils\param_validation.py:72: UserWarning: The given float value must not exceed 0.3054807880993974. But, you have given threshold=1.644854
#   warnings.warn("The given float value must not exceed {0}. "
# WARNING:nimare.diagnostics:No clusters found
# (5, 0)
# Empty DataFrame
# Columns: []
# Index: [Center of Mass, Abler et al-From uncertainty to reward - B.. Table 1-4: fMRI Results: ANOVA 1 - modeling effects over the whole trial - increasing reward uncertainty, Lawrence et al-Distinct Roles of Prefrontal C.. Table 2 - Brain regions showing significant activation during choices from risky (A/B) versus safe (C/D) decks and showing a correlation with task performance, Xue et al-Functional Dissociations of Ri.. Table S3 - Foci of activation for Risky minus Safe choices across both Gain and Loss domains, Xue et al-Functional Dissociations of Ri.. Table S6 - Foci of regions showing significant positive correlation between individual risk preference and activation in Win vs. Loss contrast]
# select08_reward_outcome_high-low
# 100%|██████████| 12/12 [00:00<00:00, 86.88it/s]
# (13, 2)
#                                                              1             2
# Cluster ID
# Center of Mass                                      (1, 36, 9)  (0, -32, 30)
# Abler et al-From uncertainty to reward - B.. Ta...           0             0
# Abler et al-From uncertainty to reward - B.. Ta...           0             0
# Cloutier et al-Are Attractive People Rewardin.....           2             0
# Delgado et al-Dorsal striatum responses to r.. ...           0             0
# Elliott et al-Dissociable Neural Responses i.. ...           0             0
# Jarcho et al-Developmental effects of decis.. T...           0             0
# Jarcho et al-Developmental effects of decis.. T...           0             1
# Knutson et al-Dissociation of reward anticip.. ...           0             0
# Nieuwenhuis et al-Activity in human reward-sens...           0             0
# Nieuwenhuis et al-Activity in human reward-sens...           0             1
# Signe Bray and John O'Doherty-Neural Coding of ...           1             1
# Winston et al-Brain systems for assessing fa.. ...           1             0
# select09_reward_outcome_win-lose
# C:\ProgramData\Anaconda3\envs\tfg-env\lib\site-packages\nilearn\_utils\param_validation.py:72: UserWarning: The given float value must not exceed 1.1263911290388007. But, you have given threshold=1.644854
#   warnings.warn("The given float value must not exceed {0}. "
# WARNING:nimare.diagnostics:No clusters found
# (8, 0)
# Empty DataFrame
# Columns: []
# Index: [Center of Mass, Christakou et al-Right Ventromedial and Dorsola.. Table 1 - Conjunction of whole-brain correlations of choice and EV-modulated outcome contrasts with net score, Fujiwara et al-Segregated and Integrated Codi.. TABLE 1 - Gain-specific regions in the cingulate + TABLE 2 - Gain-specific regions outside the cingulate, Greck et al-Is our self based on reward - .. Table 1 - Activations for the contrast [reward win] vs [reward lose] - in fMRI the contrast was bigger for the won trials than those lost, Lawrence et al-Distinct Roles of Prefrontal C.. Table 3 - Brain regions showing significant activation in response to wins versus losses (all decks), Vassena et al-Dissociating contributions of .. Table 1-1  Summary of the activations in the whole brain contrasts. Contrast outcome phase win > lose, Xue et al-Functional Dissociations of Ri.. Table S4 - Foci of activation for Win minus Loss domains across both Risky and Safe choices, Xue et al-Functional Dissociations of Ri.. Table S6 - Foci of regions showing significant positive correlation between individual risk preference and activation in Win vs. Loss contrast]
# select10_reward_decision-making_outcome
# 100%|██████████| 63/63 [00:00<00:00, 67.68it/s]
# (64, 4)
#                                                                1            2  \
# Cluster ID
# Center of Mass                                      (14, 10, -6)  (0, 54, 15)
# Abler et al-From uncertainty to reward - B.. Ta...             0            0
# Abler et al-From uncertainty to reward - B.. Ta...             0            0
# Abler et al-From uncertainty to reward - B.. Ta...             0            0
# Abler et al-From uncertainty to reward - B.. Ta...             1            0
# ...                                                          ...          ...
# Xue et al-Functional Dissociations of Ri.. Tabl...             0            1
# Xue et al-Functional Dissociations of Ri.. Tabl...             1            0
# Xue et al-Functional Dissociations of Ri.. Tabl...             0            0
# Xue et al-Functional Dissociations of Ri.. Tabl...             2            0
# Xue et al-Functional Dissociations of Ri.. Tabl...             0            0
#
#                                                              3              4
# Cluster ID
# Center of Mass                                      (-6, 5, 0)  (-18, 7, -13)
# Abler et al-From uncertainty to reward - B.. Ta...           0              0
# Abler et al-From uncertainty to reward - B.. Ta...           1              0
# Abler et al-From uncertainty to reward - B.. Ta...           0              0
# Abler et al-From uncertainty to reward - B.. Ta...           1              0
# ...                                                        ...            ...
# Xue et al-Functional Dissociations of Ri.. Tabl...           1              0
# Xue et al-Functional Dissociations of Ri.. Tabl...           0              2
# Xue et al-Functional Dissociations of Ri.. Tabl...           1              0
# Xue et al-Functional Dissociations of Ri.. Tabl...           0              1
# Xue et al-Functional Dissociations of Ri.. Tabl...           0              0
#
# [64 rows x 4 columns]
# select11_reward_decision-making_anticipation
# 100%|██████████| 18/18 [00:00<00:00, 93.18it/s]
# (19, 2)
#                                                               1           2
# Cluster ID
# Center of Mass                                      (0, 26, 42)  (-6, 6, 1)
# Abler et al-From uncertainty to reward - B.. Ta...            0           1
# Abler et al-From uncertainty to reward - B.. Ta...            0           1
# Abler et al-From uncertainty to reward - B.. Ta...            0           0
# Abler et al-From uncertainty to reward - B.. Ta...            0           0
# Abler et al-From uncertainty to reward - B.. Ta...            0           0
# Cohen et al-Individual differences in extr.. Ta...            0           0
# Jarcho et al-Developmental effects of decis.. T...            1           0
# Jarcho et al-Developmental effects of decis.. T...            0           0
# Jarcho et al-Developmental effects of decis.. T...            0           0
# Jarcho et al-Developmental effects of decis.. T...            0           0
# Koeneke et al-Individual preferences modulat.. ...            0           0
# Rosell-Negre et al-Monetary reward magnitude ef...            0           1
# Smith et al-Neural substrates of reward ma.. Ta...            0           0
# Smith et al-Neural substrates of reward ma.. Ta...            1           0
# Smith et al-Neural substrates of reward ma.. Ta...            1           0
# Tobler et al-Reward Value Coding Distinct F.. T...            0           1
# Tobler et al-Reward Value Coding Distinct F.. T...            0           0
# Tobler et al-Reward Value Coding Distinct F.. T...            0           0
# select12_reward_decision-making_decision
# 100%|██████████| 7/7 [00:00<00:00, 112.80it/s]
# (8, 1)
#                                                                  1
# Cluster ID
# Center of Mass                                      (-28, -91, -4)
# Lawrence et al-Distinct Roles of Prefrontal C.....               0
# Rogers et al-Distinct Portions of Anterior .. T...               0
# Rogers et al-Distinct Portions of Anterior .. T...               0
# Schonberg et al-Decreasing ventromedial prefro....               1
# Schonberg et al-Decreasing ventromedial prefro....               1
# Vassena et al-Dissociating contributions of .. ...               0
# Vassena et al-Dissociating contributions of .. ...               1

# %%
## Save statistics tables
for file_name, tbl in fcscnt_tables.items():
    path_xls = os.path.join(os.path.abspath(_statistics_folder), file_name + '_by_grp' + '.xls')
    path_csv = os.path.join(os.path.abspath(_statistics_folder), file_name + '_by_grp' + '.csv')
    tbl.to_excel(path_xls)
    tbl.to_csv(path_csv)
# Out:
# C:\Users\Chh\AppData\Local\Temp\ipykernel_4376\513553238.py:5: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   tbl.to_excel(path_xls)

# %% [markdown]
# ## Conjunctions

# %%
import copy
from nilearn.image import math_img
import numpy as np

# %%
tmp_imgs = copy.deepcopy(imgs)

# %%
dict_keys = list(tmp_imgs.keys())
dict_keys
# Out:
# ['select00_test',
#  'select01_wm',
#  'select02_wm_decision-making',
#  'select03_reward_anticipation_rw-norw',
#  'select04_reward_anticipation_high_low_rew',
#  'select05_reward_anticipation_exp_recv_rew',
#  'select06_reward_outcome_rw-norw',
#  'select07_reward_outcome_risk-safe',
#  'select08_reward_outcome_high-low',
#  'select09_reward_outcome_win-lose',
#  'select10_reward_decision-making_outcome',
#  'select11_reward_decision-making_anticipation',
#  'select12_reward_decision-making_decision']

# %%
# %%time
formula = "np.where(img1 * img2 > 0, np.minimum(img1, img2), 0)"
img_conj = math_img(formula,
                    img1=copy.deepcopy(tmp_imgs[dict_keys[6]]),
                    img2=copy.deepcopy(tmp_imgs[dict_keys[10]]))
num_vox = np.sum(img_conj.get_fdata() > 0)
print(np.max(img_conj.get_fdata()))
num_vox
# Out:
# 0.6128129910166272
# CPU times: total: 375 ms
# Wall time: 373 ms
# 25

# %% [markdown]
# TEST the conjunctions 3 vs 2x2
# //1,4,12
# //3 4 11

# %%
# %%time
formula = "np.where(img1 * img2 * img3 > 0, np.minimum(img1, img2,img3), 0)"
img_conj1 = math_img(formula,
                     img1=copy.deepcopy(tmp_imgs[dict_keys[3]]),
                     img2=copy.deepcopy(tmp_imgs[dict_keys[6]]),
                     img3=copy.deepcopy(tmp_imgs[dict_keys[10]]))
num_vox = np.sum(img_conj1.get_fdata() > 0)
print(np.max(img_conj1.get_fdata()))
num_vox
# Out:
# 0.10043372051146988
# CPU times: total: 609 ms
# Wall time: 600 ms
# 17

# %%
# %%time
formula = "np.where(img1 * img2 > 0, np.minimum(img1, img2), 0)"
img_conj2 = math_img(formula,
                     img1=copy.deepcopy(img_conj1),
                     img2=copy.deepcopy(tmp_imgs[dict_keys[10]]))
num_vox = np.sum(img_conj2.get_fdata() > 0)
print(np.max(img_conj2.get_fdata()))
num_vox
# Out:
# 2.3263478740408408
# CPU times: total: 375 ms
# Wall time: 366 ms
# 29

# %%
# %%time
formula = "np.where(img1 * img2 > 0, np.minimum(img1, img2), 0)"
img_conj3 = math_img(formula,
                     img1=copy.deepcopy(img_conj2),
                     img2=copy.deepcopy(tmp_imgs[dict_keys[11]]))
num_vox = np.sum(img_conj3.get_fdata() > 0)
print(np.max(img_conj3.get_fdata()))
num_vox
# Out:
# 2.3263478740408408
# CPU times: total: 359 ms
# Wall time: 365 ms
# 23

# %% [markdown]
# ### Get non null pixels

# %%
# t1_data = img_conj.get_fdata()
# t1_data.shape
#
# Out:
# (91, 109, 91)

# %%
# pts_lst = []
# for i in range(t1_data.shape[0]):
#     for j in range(t1_data.shape[1]):
#         for k in range(t1_data.shape[2]):
#             if t1_data[i, j, k] != 0: pts_lst.append([i, j, k])
#

# %%
# pts_lst
# Out:
# [[28, 74, 36],
#  [28, 74, 37],
#  [28, 74, 38],
#  [28, 75, 37],
#  [28, 75, 38],
#  [28, 76, 38],
#  [29, 74, 36],
#  [29, 74, 37],
#  [29, 74, 38],
#  [29, 75, 36],
#  [29, 75, 37],
#  [29, 75, 38],
#  [29, 76, 37],
#  [29, 76, 38],
#  [29, 77, 38],
#  [30, 75, 36],
#  [30, 75, 37],
#  [30, 76, 36],
#  [30, 76, 37]]

# %% [markdown]
# ## Save img to nifti

# %%
img_to_save = img_conj
img_name = 'img_combo2_5'
nib.save(img_to_save, os.path.join(os.path.abspath(_nii_combos_folder), img_name + '.nii'))
print(np.sum(img_to_save.get_fdata() > 0))
print(np.max(img_to_save.get_fdata()))
# Out:
# 6
# 1.1263911290388007

# %% [markdown]
# ## recursive conjunctions

# %%
# Create a base nifti
base_img = math_img("np.where(img1  > 0, 10000,10000)", img1=copy.deepcopy(tmp_imgs[dict_keys[0]]))

# %%
### !! Check for empty maps
rec_list = ['base_img',
            'select01_wm',
            'select02_wm_decision-making',
            'select03_reward_anticipation_rw-norw',
            'select04_reward_anticipation_high_low_rew',
            'select05_reward_anticipation_exp_recv_rew',
            'select06_reward_outcome_rw-norw',
            'select07_reward_outcome_risk-safe',
            'select08_reward_outcome_high-low',
            'select09_reward_outcome_win-lose',
            'select10_reward_decision-making_outcome',
            'select11_reward_decision-making_anticipation',
            'select12_reward_decision-making_decision']
# ['base_img'] + list(tmp_imgs.keys()) # - select00_test
rec_list
# Out:
# ['base_img',
#  'select01_wm',
#  'select02_wm_decision-making',
#  'select03_reward_anticipation_rw-norw',
#  'select04_reward_anticipation_high_low_rew',
#  'select05_reward_anticipation_exp_recv_rew',
#  'select06_reward_outcome_rw-norw',
#  'select07_reward_outcome_risk-safe',
#  'select08_reward_outcome_high-low',
#  'select09_reward_outcome_win-lose',
#  'select10_reward_decision-making_outcome',
#  'select11_reward_decision-making_anticipation',
#  'select12_reward_decision-making_decision']

# %%
path_set = set()
tmp_imgs['base_img'] = base_img

# %%
formula = "np.where(img1 * img2 > 0, np.minimum(img1, img2), 0)"


def recursive_conjunction(index, img_conj, path):
    if index == len(rec_list): return
    img_conj = math_img(formula, img1=copy.deepcopy(img_conj), img2=copy.deepcopy(tmp_imgs[rec_list[index]]))
    if np.sum(img_conj.get_fdata() > 0):
        path_set.add(tuple(path))
    else:
        return
    print(tuple(path))
    for i in range(index + 1, len(rec_list) + 1):
        recursive_conjunction(i, copy.deepcopy(img_conj), path + [i])
    return

# %%
recursive_conjunction(0, base_img, [])
# Out:
# ()
# (1,)
# (1, 3)
# (1, 8)
# (1, 11)
# (2,)
# (3,)
# (3, 4)
# (3, 4, 8)
# (3, 4, 8, 10)
# (3, 4, 8, 10, 11)
# (3, 4, 8, 11)
# (3, 4, 10)
# (3, 4, 10, 11)
# (3, 4, 11)
# (3, 4, 12)
# (3, 6)
# (3, 6, 10)
# (3, 8)
# (3, 8, 10)
# (3, 8, 10, 11)
# (3, 8, 11)
# (3, 10)
# (3, 10, 11)
# (3, 11)
# (3, 12)
# (4,)
# (4, 8)
# (4, 8, 10)
# (4, 8, 10, 11)
# (4, 8, 11)
# (4, 10)
# (4, 10, 11)
# (4, 11)
# (4, 12)
# (5,)
# (6,)
# (6, 10)
# (7,)
# (8,)
# (8, 9)
# (8, 10)
# (8, 10, 11)
# (8, 11)
# (8, 12)
# (9,)
# (10,)
# (10, 11)
# (11,)
# (12,)

# %%
print(path_set)
# Out:
# {(2,), (3, 4, 8, 10, 11), (3, 4), (4, 8, 11), (3, 8, 10, 11), (5,), (11,), (4, 10, 11), (4, 12), (3, 10), (8,), (8, 9), (3, 10, 11), (8, 12), (1, 3), (3, 6, 10), (3, 4, 10), (3, 8, 10), (3, 4, 8, 11), (3, 4, 10, 11), (4,), (1,), (7,), (4, 8, 10), (4, 8), (3, 6), (3, 12), (10,), (4, 11), (8, 11), (10, 11), (1, 11), (1, 8), (8, 10, 11), (3, 4, 12), (4, 8, 10, 11), (6, 10), (3, 4, 8, 10), (3,), (9,), (3, 11), (6,), (4, 10), (3, 8), (12,), (8, 10), (3, 4, 8), (3, 4, 11), (), (3, 8, 11)}

# %% [markdown]
# ## Save models to pickle

# %%
path_set_file_name = r'path_set.dump'
pickle.dump(path_set, open(os.path.join(os.path.abspath(_res_folder), path_set_file_name), 'wb'))

# %% [markdown]
# ## Load models from pickle

# %%
retrieved_path_set = pickle.load(open(os.path.join(os.path.abspath(_res_folder), path_set_file_name), 'rb'))
retrieved_path_set
# Out:
# {(),
#  (1,),
#  (1, 3),
#  (1, 8),
#  (1, 11),
#  (2,),
#  (3,),
#  (3, 4),
#  (3, 4, 8),
#  (3, 4, 8, 10),
#  (3, 4, 8, 10, 11),
#  (3, 4, 8, 11),
#  (3, 4, 10),
#  (3, 4, 10, 11),
#  (3, 4, 11),
#  (3, 4, 12),
#  (3, 6),
#  (3, 6, 10),
#  (3, 8),
#  (3, 8, 10),
#  (3, 8, 10, 11),
#  (3, 8, 11),
#  (3, 10),
#  (3, 10, 11),
#  (3, 11),
#  (3, 12),
#  (4,),
#  (4, 8),
#  (4, 8, 10),
#  (4, 8, 10, 11),
#  (4, 8, 11),
#  (4, 10),
#  (4, 10, 11),
#  (4, 11),
#  (4, 12),
#  (5,),
#  (6,),
#  (6, 10),
#  (7,),
#  (8,),
#  (8, 9),
#  (8, 10),
#  (8, 10, 11),
#  (8, 11),
#  (8, 12),
#  (9,),
#  (10,),
#  (10, 11),
#  (11,),
#  (12,)}

# %%
lst_models = list(retrieved_path_set)
lst_models.sort(key=lambda x: len(x) if type(x) is tuple else 1)
# lst_models = [tuple(x - 1 for x in tupl) for tupl in lst_models]
display(lst_models)
# Out:
# [(),
#  (2,),
#  (5,),
#  (11,),
#  (8,),
#  (4,),
#  (1,),
#  (7,),
#  (10,),
#  (3,),
#  (9,),
#  (6,),
#  (12,),
#  (3, 4),
#  (4, 12),
#  (3, 10),
#  (8, 9),
#  (8, 12),
#  (1, 3),
#  (4, 8),
#  (3, 6),
#  (3, 12),
#  (4, 11),
#  (8, 11),
#  (10, 11),
#  (1, 11),
#  (1, 8),
#  (6, 10),
#  (3, 11),
#  (4, 10),
#  (3, 8),
#  (8, 10),
#  (4, 8, 11),
#  (4, 10, 11),
#  (3, 10, 11),
#  (3, 6, 10),
#  (3, 4, 10),
#  (3, 8, 10),
#  (4, 8, 10),
#  (8, 10, 11),
#  (3, 4, 12),
#  (3, 4, 8),
#  (3, 4, 11),
#  (3, 8, 11),
#  (3, 8, 10, 11),
#  (3, 4, 8, 11),
#  (3, 4, 10, 11),
#  (4, 8, 10, 11),
#  (3, 4, 8, 10),
#  (3, 4, 8, 10, 11)]

# %%
# Write path_list to csv
lst_file_name = r'path_list.dump'
pickle.dump(path_set, open(os.path.join(os.path.abspath(_res_folder), lst_file_name), 'wb'))

# writing the data into the file
lst_file_name_csv = r'path_list.csv'
with open(os.path.join(os.path.abspath(_res_folder), lst_file_name_csv), 'w', newline='') as f:
    write = csv.writer(f)
    write.writerows(lst_models)

# %% [markdown]
# ## Convert to BA

# %%
lst_models = [list(x) for x in lst_models]
lst_models
# Out:
# [[],
#  [2],
#  [5],
#  [11],
#  [8],
#  [4],
#  [1],
#  [7],
#  [10],
#  [3],
#  [9],
#  [6],
#  [12],
#  [3, 4],
#  [4, 12],
#  [3, 10],
#  [8, 9],
#  [8, 12],
#  [1, 3],
#  [4, 8],
#  [3, 6],
#  [3, 12],
#  [4, 11],
#  [8, 11],
#  [10, 11],
#  [1, 11],
#  [1, 8],
#  [6, 10],
#  [3, 11],
#  [4, 10],
#  [3, 8],
#  [8, 10],
#  [4, 8, 11],
#  [4, 10, 11],
#  [3, 10, 11],
#  [3, 6, 10],
#  [3, 4, 10],
#  [3, 8, 10],
#  [4, 8, 10],
#  [8, 10, 11],
#  [3, 4, 12],
#  [3, 4, 8],
#  [3, 4, 11],
#  [3, 8, 11],
#  [3, 8, 10, 11],
#  [3, 4, 8, 11],
#  [3, 4, 10, 11],
#  [4, 8, 10, 11],
#  [3, 4, 8, 10],
#  [3, 4, 8, 10, 11]]

# %% [markdown]
# ### Eliminate the singular models
# Only the empty one

# %%
lst_models = [x for x in lst_models if len(x)]  #and len(x) > 1]
len(lst_models)
# Out:
# 49

# %% [markdown]
# ### Create the Conjugate images

# %%
import tqdm

# %%
formula = "np.where(img1 * img2 > 0, np.minimum(img1, img2), 0)"
img_conjugates = []
for model in tqdm.tqdm(lst_models):
    if not model: continue
    img_conj = copy.deepcopy(base_img)
    for i in range(len(model)):
        img_conj = math_img(formula,
                            img1=copy.deepcopy(img_conj),
                            img2=copy.deepcopy(tmp_imgs[dict_keys[model[i]]]))
    # num_vox = np.sum(img_conj.get_fdata() > 0)
    img_conjugates.append(img_conj)
# Out:
# 100%|██████████| 49/49 [00:29<00:00,  1.64it/s]

# %% [markdown]
# ### Obtain non null coordinates

# %%
def get_non_null_nifti_val(nifti):
    pts_lst = []
    for i in range(nifti.get_fdata().shape[0]):
        for j in range(nifti.get_fdata().shape[1]):
            for k in range(nifti.get_fdata().shape[2]):
                if nifti.get_fdata()[i, j, k] != 0: pts_lst.append([i, j, k])
    return pts_lst

# %%
pts_list_conj = []
for img in tqdm.tqdm(img_conjugates):
    pts_list_conj.append(get_non_null_nifti_val(img))
# Out:
# 100%|██████████| 49/49 [00:32<00:00,  1.52it/s]

# %% [markdown]
# ### Convert the Coordinates

# %%
from scipy.interpolate import interp1d
import util.function_conv_mni as util_conv
import importlib

importlib.reload(util_conv)
# Out:
# <module 'util.function_conv_mni' from 'D:\\scul\\uaic-ub\\licenta\\code\\util\\function_conv_mni.py'>

# %%
#Interpolation
X = [[1, 91], [1, 109], [1, 91]]
Y = [[-90, 90], [-126, 90], [-72, 108]]
# test value
x_interp = interp1d(X[0], Y[0])
y_interp = interp1d(X[1], Y[1])
z_interp = interp1d(X[2], Y[2])

# %%
pts_list_conj_conv = []
for pts in pts_list_conj:
    pts_list_conj_conv.append([[x_interp(x).item(), y_interp(y).item(), z_interp(z).item()] for x, y, z in pts])

# %%
one_line_lst = []
table_lst = []
for pts in pts_list_conj_conv:
    one_line, table = util_conv.find_structure(pts)
    one_line_lst.append(one_line)
    table_lst.append(table)

# %%
# for i in range(len(one_line_lst[34])):
#     print(one_line_lst[34][i])

# %% [markdown]
# ### Parse the results

# %%
one_line_lst_parsed = []
for ind, results in enumerate(one_line_lst):
    set_lst = [set() for x in range(7)]
    set_lst[0] = (ind, lst_models[ind])
    for result in results:
        for index, el in enumerate(result.split("//")):
            if index == 0 or el.rstrip().lstrip() == 'undefined': continue
            set_lst[index].add(el)
    one_line_lst_parsed.append(set_lst)

# %%
display(one_line_lst_parsed)
# Out:
# [[(0, [2]),
#   {' Left Cerebrum ', ' Right Cerebrum '},
#   {' Parietal Lobe '},
#   {' Inferior Parietal Lobule ',
#    ' Precuneus ',
#    ' Sub-Gyral ',
#    ' Superior Parietal Lobule '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 19 ', ' brodmann area 39 ', ' brodmann area 7 '},
#   {' Angular_L (aal)',
#    ' Occipital_Mid_L (aal)',
#    ' Parietal_Inf_L (aal)',
#    ' Parietal_Sup_R (aal)',
#    ' Precuneus_R (aal)'}],
#  [(1, [5]),
#   {' Left Cerebrum '},
#   {' Parietal Lobe ', ' Sub-lobar ', ' Temporal Lobe '},
#   {' Extra-Nuclear ', ' Insula ', ' Sub-Gyral ', ' Superior Temporal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 13 ', ' brodmann area 41 '},
#   {' Rolandic_Oper_L (aal)', ' Temporal_Sup_L (aal)'}],
#  [(2, [11]),
#   {' Inter-Hemispheric ', ' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Cingulate Gyrus ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle ',
#    ' Medial Frontal Gyrus ',
#    ' Thalamus ',
#    ' Third Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ',
#    ' Caudate Head ',
#    ' Lateral Posterior Nucleus ',
#    ' Medial Globus Pallidus ',
#    ' Pulvinar ',
#    ' Ventral Lateral Nucleus ',
#    ' brodmann area 25 ',
#    ' brodmann area 32 ',
#    ' brodmann area 6 ',
#    ' brodmann area 8 '},
#   {' Caudate_R (aal)',
#    ' Cingulum_Mid_L (aal)',
#    ' Cingulum_Mid_R (aal)',
#    ' Frontal_Sup_Medial_L (aal)',
#    ' Frontal_Sup_Medial_R (aal)',
#    ' Supp_Motor_Area_L (aal)',
#    ' Thalamus_L (aal)'}],
#  [(3, [8]),
#   {' Inter-Hemispheric ', ' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Cingulate Gyrus ',
#    ' Claustrum ',
#    ' Extra-Nuclear ',
#    ' Inferior Frontal Gyrus ',
#    ' Insula ',
#    ' Lateral Ventricle ',
#    ' Middle Frontal Gyrus ',
#    ' Posterior Cingulate ',
#    ' Precentral Gyrus ',
#    ' Sub-Gyral '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Caudate Head ',
#    ' Corpus Callosum ',
#    ' brodmann area 13 ',
#    ' brodmann area 23 ',
#    ' brodmann area 24 ',
#    ' brodmann area 25 ',
#    ' brodmann area 31 ',
#    ' brodmann area 32 ',
#    ' brodmann area 45 ',
#    ' brodmann area 47 ',
#    ' brodmann area 6 ',
#    ' brodmann area 9 '},
#   {' Caudate_R (aal)',
#    ' Cingulum_Ant_L (aal)',
#    ' Cingulum_Ant_R (aal)',
#    ' Cingulum_Mid_R (aal)',
#    ' Cingulum_Post_L (aal)',
#    ' Frontal_Inf_Oper_R (aal)',
#    ' Frontal_Inf_Orb_L (aal)',
#    ' Frontal_Inf_Tri_L (aal)',
#    ' Frontal_Mid_R (aal)',
#    ' Insula_L (aal)',
#    ' Olfactory_R (aal)',
#    ' Precentral_R (aal)',
#    ' Putamen_R (aal)'}],
#  [(4, [4]),
#   {' Inter-Hemispheric ', ' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Cingulate Gyrus ',
#    ' Extra-Nuclear ',
#    ' Inferior Frontal Gyrus ',
#    ' Insula ',
#    ' Lateral Ventricle ',
#    ' Lentiform Nucleus ',
#    ' Sub-Gyral ',
#    ' Subcallosal Gyrus ',
#    ' Thalamus '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ',
#    ' Caudate Head ',
#    ' Hypothalamus ',
#    ' Lateral Globus Pallidus ',
#    ' Medial Globus Pallidus ',
#    ' Putamen ',
#    ' brodmann area 13 ',
#    ' brodmann area 24 ',
#    ' brodmann area 25 ',
#    ' brodmann area 32 ',
#    ' brodmann area 33 ',
#    ' brodmann area 47 '},
#   {' Caudate_L (aal)',
#    ' Caudate_R (aal)',
#    ' Cingulum_Ant_L (aal)',
#    ' Frontal_Inf_Orb_L (aal)',
#    ' Frontal_Sup_Orb_L (aal)',
#    ' Insula_L (aal)',
#    ' Olfactory_L (aal)',
#    ' Olfactory_R (aal)',
#    ' Pallidum_L (aal)',
#    ' Pallidum_R (aal)',
#    ' Putamen_L (aal)',
#    ' Putamen_R (aal)',
#    ' Rectus_L (aal)',
#    ' Rectus_R (aal)'}],
#  [(5, [1]),
#   {' Inter-Hemispheric ', ' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Parietal Lobe ', ' Sub-lobar '},
#   {' Angular Gyrus ',
#    ' Cingulate Gyrus ',
#    ' Claustrum ',
#    ' Extra-Nuclear ',
#    ' Inferior Frontal Gyrus ',
#    ' Inferior Parietal Lobule ',
#    ' Insula ',
#    ' Lentiform Nucleus ',
#    ' Medial Frontal Gyrus ',
#    ' Middle Frontal Gyrus ',
#    ' Precentral Gyrus ',
#    ' Precuneus ',
#    ' Sub-Gyral ',
#    ' Superior Frontal Gyrus ',
#    ' Superior Parietal Lobule ',
#    ' Supramarginal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' Putamen ',
#    ' brodmann area 10 ',
#    ' brodmann area 13 ',
#    ' brodmann area 32 ',
#    ' brodmann area 40 ',
#    ' brodmann area 45 ',
#    ' brodmann area 46 ',
#    ' brodmann area 47 ',
#    ' brodmann area 6 ',
#    ' brodmann area 7 ',
#    ' brodmann area 8 ',
#    ' brodmann area 9 '},
#   {' Angular_L (aal)',
#    ' Angular_R (aal)',
#    ' Cingulum_Mid_L (aal)',
#    ' Cingulum_Mid_R (aal)',
#    ' Cuneus_R (aal)',
#    ' Frontal_Inf_Oper_R (aal)',
#    ' Frontal_Inf_Orb_R (aal)',
#    ' Frontal_Inf_Tri_L (aal)',
#    ' Frontal_Mid_L (aal)',
#    ' Frontal_Mid_Orb_R (aal)',
#    ' Frontal_Mid_R (aal)',
#    ' Frontal_Sup_L (aal)',
#    ' Frontal_Sup_Medial_L (aal)',
#    ' Frontal_Sup_Medial_R (aal)',
#    ' Frontal_Sup_R (aal)',
#    ' Insula_R (aal)',
#    ' Occipital_Mid_R (aal)',
#    ' Occipital_Sup_R (aal)',
#    ' Parietal_Inf_L (aal)',
#    ' Parietal_Inf_R (aal)',
#    ' Parietal_Sup_L (aal)',
#    ' Parietal_Sup_R (aal)',
#    ' Precentral_L (aal)',
#    ' Precentral_R (aal)',
#    ' Precuneus_R (aal)',
#    ' Putamen_R (aal)',
#    ' Supp_Motor_Area_L (aal)',
#    ' Supp_Motor_Area_R (aal)'}],
#  [(6, [7]),
#   {' Right Cerebrum '},
#   {' Frontal Lobe ', ' Temporal Lobe '},
#   {' Inferior Frontal Gyrus ', ' Superior Temporal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 38 ', ' brodmann area 47 '},
#   {' Frontal_Inf_Orb_R (aal)', ' Insula_R (aal)'}],
#  [(7, [10]),
#   {' Inter-Hemispheric ',
#    ' Left Cerebrum ',
#    ' Right Brainstem ',
#    ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Midbrain ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Inferior Frontal Gyrus ',
#    ' Lateral Ventricle ',
#    ' Lentiform Nucleus ',
#    ' Medial Frontal Gyrus ',
#    ' Orbital Gyrus ',
#    ' Parahippocampa Gyrus ',
#    ' Sub-Gyral ',
#    ' Subcallosal Gyrus ',
#    ' Superior Frontal Gyrus ',
#    ' Thalamus ',
#    ' Third Ventricle ',
#    ' Uncus '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ',
#    ' Caudate Head ',
#    ' Lateral Globus Pallidus ',
#    ' Medial Globus Pallidus ',
#    ' Putamen ',
#    ' brodmann area 10 ',
#    ' brodmann area 11 ',
#    ' brodmann area 13 ',
#    ' brodmann area 25 ',
#    ' brodmann area 32 ',
#    ' brodmann area 34 ',
#    ' brodmann area 47 ',
#    ' brodmann area 9 '},
#   {' Caudate_L (aal)',
#    ' Caudate_R (aal)',
#    ' Cingulum_Ant_L (aal)',
#    ' Cingulum_Ant_R (aal)',
#    ' Frontal_Med_Orb_L (aal)',
#    ' Frontal_Med_Orb_R (aal)',
#    ' Frontal_Sup_L (aal)',
#    ' Frontal_Sup_Medial_L (aal)',
#    ' Frontal_Sup_Medial_R (aal)',
#    ' Hippocampus_R (aal)',
#    ' Olfactory_L (aal)',
#    ' Olfactory_R (aal)',
#    ' Pallidum_L (aal)',
#    ' ParaHippocampal_R (aal)',
#    ' Putamen_L (aal)',
#    ' Putamen_R (aal)',
#    ' Rectus_L (aal)',
#    ' Rectus_R (aal)'}],
#  [(8, [3]),
#   {' Inter-Hemispheric ',
#    ' Left Brainstem ',
#    ' Left Cerebrum ',
#    ' Right Brainstem ',
#    ' Right Cerebrum '},
#   {' Frontal Lobe ',
#    ' Limbic Lobe ',
#    ' Midbrain ',
#    ' Sub-lobar ',
#    ' Temporal Lobe '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Cingulate Gyrus ',
#    ' Extra-Nuclear ',
#    ' Inferior Frontal Gyrus ',
#    ' Insula ',
#    ' Lateral Ventricle ',
#    ' Lentiform Nucleus ',
#    ' Medial Frontal Gyrus ',
#    ' Parahippocampa Gyrus ',
#    ' Sub-Gyral ',
#    ' Subcallosal Gyrus ',
#    ' Superior Temporal Gyrus ',
#    ' Thalamus '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Amygdala ',
#    ' Anterior Commissure ',
#    ' Caudate Head ',
#    ' Hypothalamus ',
#    ' Lateral Globus Pallidus ',
#    ' Medial Dorsal Nucleus ',
#    ' Medial Globus Pallidus ',
#    ' Putamen ',
#    ' Red Nucleus ',
#    ' Substania Nigra ',
#    ' Subthalamic Nucleus ',
#    ' Ventral Anterior Nucleus ',
#    ' Ventral Lateral Nucleus ',
#    ' brodmann area 13 ',
#    ' brodmann area 24 ',
#    ' brodmann area 25 ',
#    ' brodmann area 32 ',
#    ' brodmann area 34 ',
#    ' brodmann area 38 ',
#    ' brodmann area 47 ',
#    ' brodmann area 9 '},
#   {' Amygdala_R (aal)',
#    ' Caudate_L (aal)',
#    ' Caudate_R (aal)',
#    ' Cingulum_Ant_L (aal)',
#    ' Cingulum_Mid_L (aal)',
#    ' Frontal_Inf_Orb_L (aal)',
#    ' Frontal_Sup_Medial_L (aal)',
#    ' Insula_L (aal)',
#    ' Olfactory_L (aal)',
#    ' Olfactory_R (aal)',
#    ' Pallidum_L (aal)',
#    ' Putamen_L (aal)',
#    ' Putamen_R (aal)',
#    ' Rectus_L (aal)',
#    ' Supp_Motor_Area_L (aal)',
#    ' Temporal_Pole_Sup_L (aal)',
#    ' Thalamus_L (aal)',
#    ' Thalamus_R (aal)'}],
#  [(9, [9]),
#   {' Inter-Hemispheric ', ' Left Cerebrum ', ' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ', ' Extra-Nuclear '},
#   {' Gray Matter ', ' White Matter '},
#   {' Corpus Callosum ', ' brodmann area 24 ', ' brodmann area 32 '},
#   {' Cingulum_Ant_L (aal)', ' Cingulum_Ant_R (aal)'}],
#  [(10, [6]),
#   {' Inter-Hemispheric ',
#    ' Left Brainstem ',
#    ' Left Cerebrum ',
#    ' Right Brainstem ',
#    ' Right Cerebrum '},
#   {' Frontal Lobe ',
#    ' Limbic Lobe ',
#    ' Midbrain ',
#    ' Pons ',
#    ' Sub-lobar ',
#    ' Temporal Lobe '},
#   {' Anterior Cingulate ',
#    ' Extra-Nuclear ',
#    ' Inferior Frontal Gyrus ',
#    ' Lateral Ventricle ',
#    ' Lentiform Nucleus ',
#    ' Medial Frontal Gyrus ',
#    ' Parahippocampa Gyrus ',
#    ' Sub-Gyral ',
#    ' Subcallosal Gyrus ',
#    ' Superior Temporal Gyrus ',
#    ' Uncus '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Putamen ',
#    ' brodmann area 10 ',
#    ' brodmann area 11 ',
#    ' brodmann area 32 ',
#    ' brodmann area 34 ',
#    ' brodmann area 47 '},
#   {' Amygdala_L (aal)',
#    ' Cingulum_Ant_L (aal)',
#    ' Frontal_Inf_Orb_L (aal)',
#    ' Frontal_Med_Orb_L (aal)',
#    ' Frontal_Med_Orb_R (aal)',
#    ' Fusiform_L (aal)',
#    ' Hippocampus_L (aal)',
#    ' Insula_L (aal)',
#    ' Olfactory_L (aal)',
#    ' ParaHippocampal_L (aal)',
#    ' Temporal_Pole_Sup_L (aal)'}],
#  [(11, [12]),
#   {' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Occipital Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Cingulate Gyrus ',
#    ' Cuneus ',
#    ' Extra-Nuclear ',
#    ' Inferior Frontal Gyrus ',
#    ' Inferior Occipital Gyrus ',
#    ' Insula ',
#    ' Lingual Gyrus ',
#    ' Middle Occipital Gyrus ',
#    ' Sub-Gyral '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 13 ',
#    ' brodmann area 18 ',
#    ' brodmann area 19 ',
#    ' brodmann area 24 ',
#    ' brodmann area 32 ',
#    ' brodmann area 47 '},
#   {' Calcarine_R (aal)',
#    ' Cingulum_Ant_L (aal)',
#    ' Cingulum_Mid_L (aal)',
#    ' Frontal_Sup_Medial_L (aal)',
#    ' Fusiform_R (aal)',
#    ' Insula_L (aal)',
#    ' Lingual_R (aal)',
#    ' Occipital_Inf_R (aal)',
#    ' Occipital_Mid_L (aal)',
#    ' Occipital_Mid_R (aal)'}],
#  [(12, [3, 4]),
#   {' Inter-Hemispheric ', ' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Cingulate Gyrus ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle ',
#    ' Lentiform Nucleus ',
#    ' Subcallosal Gyrus '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ',
#    ' Caudate Head ',
#    ' Hypothalamus ',
#    ' Lateral Globus Pallidus ',
#    ' Medial Globus Pallidus ',
#    ' Putamen ',
#    ' brodmann area 13 ',
#    ' brodmann area 25 ',
#    ' brodmann area 47 '},
#   {' Caudate_L (aal)',
#    ' Caudate_R (aal)',
#    ' Cingulum_Ant_L (aal)',
#    ' Olfactory_L (aal)',
#    ' Olfactory_R (aal)',
#    ' Pallidum_L (aal)',
#    ' Putamen_L (aal)',
#    ' Rectus_L (aal)'}],
#  [(13, [4, 12]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe '},
#   {' Anterior Cingulate ', ' Cingulate Gyrus ', ' Inferior Frontal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 24 ', ' brodmann area 32 ', ' brodmann area 47 '},
#   {' Cingulum_Ant_L (aal)', ' Insula_L (aal)'}],
#  [(14, [3, 10]),
#   {' Inter-Hemispheric ', ' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle ',
#    ' Lentiform Nucleus ',
#    ' Subcallosal Gyrus '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ',
#    ' Caudate Head ',
#    ' Lateral Globus Pallidus ',
#    ' Putamen ',
#    ' brodmann area 25 ',
#    ' brodmann area 34 '},
#   {' Caudate_L (aal)',
#    ' Caudate_R (aal)',
#    ' Olfactory_L (aal)',
#    ' Pallidum_L (aal)',
#    ' Putamen_L (aal)',
#    ' Rectus_L (aal)'}],
#  [(15, [8, 9]),
#   {' Left Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ', ' Extra-Nuclear '},
#   {' Gray Matter ', ' White Matter '},
#   {' Corpus Callosum ', ' brodmann area 24 '},
#   {' Cingulum_Ant_L (aal)'}],
#  [(16, [8, 12]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Extra-Nuclear ', ' Inferior Frontal Gyrus ', ' Insula '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 13 ', ' brodmann area 47 '},
#   {' Insula_L (aal)'}],
#  [(17, [1, 3]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe '},
#   {' Cingulate Gyrus ', ' Medial Frontal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 32 ', ' brodmann area 9 '},
#   {' Cingulum_Mid_L (aal)', ' Frontal_Sup_Medial_L (aal)'}],
#  [(18, [4, 8]),
#   {' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Caudate Head ', ' brodmann area 25 '},
#   {' Caudate_R (aal)'}],
#  [(19, [3, 6]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Extra-Nuclear ', ' Lentiform Nucleus ', ' Subcallosal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' Putamen ', ' brodmann area 34 '},
#   {' Olfactory_L (aal)'}],
#  [(20, [3, 12]),
#   {' Left Cerebrum '},
#   {' Limbic Lobe '},
#   {' Anterior Cingulate ', ' Cingulate Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 32 '},
#   {' Cingulum_Ant_L (aal)',
#    ' Cingulum_Mid_L (aal)',
#    ' Frontal_Sup_Medial_L (aal)'}],
#  [(21, [4, 11]),
#   {' Inter-Hemispheric ', ' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ',
#    ' Caudate Head ',
#    ' Medial Globus Pallidus ',
#    ' brodmann area 25 '},
#   {' Caudate_R (aal)'}],
#  [(22, [8, 11]),
#   {' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Caudate Head '},
#   {' Caudate_R (aal)'}],
#  [(23, [10, 11]),
#   {' Inter-Hemispheric ', ' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle ',
#    ' Third Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ', ' Caudate Head ', ' brodmann area 25 '},
#   {' Caudate_R (aal)'}],
#  [(24, [1, 11]),
#   {' Inter-Hemispheric ', ' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe '},
#   {' Cingulate Gyrus ', ' Medial Frontal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 32 ', ' brodmann area 6 '},
#   {' Cingulum_Mid_L (aal)',
#    ' Cingulum_Mid_R (aal)',
#    ' Frontal_Sup_Medial_L (aal)',
#    ' Frontal_Sup_Medial_R (aal)',
#    ' Supp_Motor_Area_L (aal)'}],
#  [(25, [1, 8]),
#   {' Right Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Claustrum ',
#    ' Extra-Nuclear ',
#    ' Inferior Frontal Gyrus ',
#    ' Insula ',
#    ' Precentral Gyrus ',
#    ' Sub-Gyral '},
#   {' Gray Matter ', ' White Matter '},
#   {' brodmann area 13 ',
#    ' brodmann area 47 ',
#    ' brodmann area 6 ',
#    ' brodmann area 9 '},
#   {' Precentral_R (aal)', ' Putamen_R (aal)'}],
#  [(26, [6, 10]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Extra-Nuclear ',
#    ' Lentiform Nucleus ',
#    ' Medial Frontal Gyrus ',
#    ' Subcallosal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' Putamen ', ' brodmann area 34 '},
#   {' Frontal_Med_Orb_L (aal)', ' Olfactory_L (aal)'}],
#  [(27, [3, 11]),
#   {' Inter-Hemispheric ', ' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ', ' Caudate Head ', ' brodmann area 25 '},
#   {' Caudate_R (aal)'}],
#  [(28, [4, 10]),
#   {' Inter-Hemispheric ', ' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle ',
#    ' Lentiform Nucleus ',
#    ' Sub-Gyral ',
#    ' Subcallosal Gyrus '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ',
#    ' Caudate Head ',
#    ' Medial Globus Pallidus ',
#    ' Putamen ',
#    ' brodmann area 13 ',
#    ' brodmann area 25 '},
#   {' Caudate_L (aal)',
#    ' Caudate_R (aal)',
#    ' Olfactory_R (aal)',
#    ' Putamen_L (aal)',
#    ' Putamen_R (aal)',
#    ' Rectus_R (aal)'}],
#  [(29, [3, 8]),
#   {' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Caudate Head ', ' brodmann area 25 '},
#   {' Caudate_R (aal)', ' Olfactory_R (aal)'}],
#  [(30, [8, 10]),
#   {' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Caudate Head '},
#   {' Caudate_R (aal)'}],
#  [(31, [4, 8, 11]),
#   {' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Caudate Head '},
#   {' Caudate_R (aal)'}],
#  [(32, [4, 10, 11]),
#   {' Inter-Hemispheric ', ' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ', ' Caudate Head ', ' brodmann area 25 '},
#   {' Caudate_R (aal)'}],
#  [(33, [3, 10, 11]),
#   {' Inter-Hemispheric ', ' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ', ' Caudate Head ', ' brodmann area 25 '},
#   {' Caudate_R (aal)'}],
#  [(34, [3, 6, 10]),
#   {' Left Cerebrum '},
#   {' Frontal Lobe ', ' Sub-lobar '},
#   {' Extra-Nuclear ', ' Lentiform Nucleus ', ' Subcallosal Gyrus '},
#   {' Gray Matter ', ' White Matter '},
#   {' Putamen ', ' brodmann area 34 '},
#   {' Olfactory_L (aal)'}],
#  [(35, [3, 4, 10]),
#   {' Inter-Hemispheric ', ' Left Cerebrum ', ' Right Cerebrum '},
#   {' Frontal Lobe ', ' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle ',
#    ' Lentiform Nucleus ',
#    ' Subcallosal Gyrus '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ',
#    ' Caudate Head ',
#    ' Putamen ',
#    ' brodmann area 25 '},
#   {' Caudate_L (aal)', ' Caudate_R (aal)', ' Putamen_L (aal)'}],
#  [(36, [3, 8, 10]),
#   {' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Caudate Head '},
#   {' Caudate_R (aal)'}],
#  [(37, [4, 8, 10]),
#   {' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Caudate Head '},
#   {' Caudate_R (aal)'}],
#  [(38, [8, 10, 11]),
#   {' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Caudate Head '},
#   {' Caudate_R (aal)'}],
#  [(39, [3, 4, 12]),
#   {' Left Cerebrum '},
#   {' Limbic Lobe '},
#   {' Cingulate Gyrus '},
#   {' White Matter '},
#   set(),
#   {' Cingulum_Ant_L (aal)'}],
#  [(40, [3, 4, 8]),
#   {' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Caudate Head ', ' brodmann area 25 '},
#   {' Caudate_R (aal)'}],
#  [(41, [3, 4, 11]),
#   {' Inter-Hemispheric ', ' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ', ' Caudate Head ', ' brodmann area 25 '},
#   {' Caudate_R (aal)'}],
#  [(42, [3, 8, 11]),
#   {' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Caudate Head '},
#   {' Caudate_R (aal)'}],
#  [(43, [3, 8, 10, 11]),
#   {' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Caudate Head '},
#   {' Caudate_R (aal)'}],
#  [(44, [3, 4, 8, 11]),
#   {' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Caudate Head '},
#   {' Caudate_R (aal)'}],
#  [(45, [3, 4, 10, 11]),
#   {' Inter-Hemispheric ', ' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Anterior Commissure ', ' Caudate Head ', ' brodmann area 25 '},
#   {' Caudate_R (aal)'}],
#  [(46, [4, 8, 10, 11]),
#   {' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Caudate Head '},
#   {' Caudate_R (aal)'}],
#  [(47, [3, 4, 8, 10]),
#   {' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Caudate Head '},
#   {' Caudate_R (aal)'}],
#  [(48, [3, 4, 8, 10, 11]),
#   {' Right Cerebrum '},
#   {' Limbic Lobe ', ' Sub-lobar '},
#   {' Anterior Cingulate ',
#    ' Caudate ',
#    ' Extra-Nuclear ',
#    ' Lateral Ventricle '},
#   {' Cerebro-Spinal Fluid ', ' Gray Matter ', ' White Matter '},
#   {' Caudate Head '},
#   {' Caudate_R (aal)'}]]

# %%
one_line_lst_parsed_2 = {}

# %%
# lst = [44,45,46]

for i in range(len(lst_models)):
    print("\nCombo: ", lst_models[i])
    lst_el = []
    for index, el in enumerate(one_line_lst[i]):
        el_striped = el.split("//")
        if el_striped[5].rstrip().lstrip() != 'undefined':
            print(pts_list_conj_conv[i][index], el)
            lst_el.append([pts_list_conj_conv[i][index], el])

    one_line_lst_parsed_2[str(lst_models[i])] = lst_el
# Out:
# Combo:  [2]
# [-36.0, -70.0, 42.0]  // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Angular_L (aal)
# [-36.0, -68.0, 40.0]  // Left Cerebrum // Parietal Lobe // Inferior Parietal Lobule // Gray Matter // brodmann area 39 // Angular_L (aal)
# [-36.0, -68.0, 42.0]  // Left Cerebrum // Parietal Lobe // Inferior Parietal Lobule // Gray Matter // brodmann area 39 // Angular_L (aal)
# [-36.0, -68.0, 44.0]  // Left Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Angular_L (aal)
# [-36.0, -66.0, 42.0]  // Left Cerebrum // Parietal Lobe // Inferior Parietal Lobule // Gray Matter // brodmann area 39 // Angular_L (aal)
# [-34.0, -70.0, 40.0]  // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)
# [-34.0, -70.0, 42.0]  // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)
# [-34.0, -70.0, 44.0]  // Left Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Angular_L (aal)
# [-34.0, -68.0, 40.0]  // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)
# [-34.0, -68.0, 42.0]  // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)
# [-34.0, -68.0, 44.0]  // Left Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Angular_L (aal)
# [-34.0, -68.0, 46.0]  // Left Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Inf_L (aal)
# [-34.0, -66.0, 40.0]  // Left Cerebrum // Parietal Lobe // Inferior Parietal Lobule // Gray Matter // brodmann area 39 // Occipital_Mid_L (aal)
# [-34.0, -66.0, 42.0]  // Left Cerebrum // Parietal Lobe // Inferior Parietal Lobule // Gray Matter // brodmann area 39 // Angular_L (aal)
# [-34.0, -66.0, 44.0]  // Left Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Inf_L (aal)
# [-32.0, -74.0, 42.0]  // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)
# [-32.0, -68.0, 38.0]  // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Occipital_Mid_L (aal)
# [-32.0, -68.0, 40.0]  // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)
# [-32.0, -68.0, 42.0]  // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)
# [-32.0, -66.0, 40.0]  // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)
# [-32.0, -66.0, 42.0]  // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)
# [-32.0, -66.0, 44.0]  // Left Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Inf_L (aal)
# [-32.0, -66.0, 46.0]  // Left Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Inf_L (aal)
# [-30.0, -74.0, 40.0]  // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Occipital_Mid_L (aal)
# [-30.0, -74.0, 42.0]  // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)
# [-28.0, -74.0, 42.0]  // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)
# [4.0, -72.0, 50.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [4.0, -70.0, 50.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [6.0, -74.0, 48.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [6.0, -74.0, 50.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [6.0, -74.0, 52.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [6.0, -72.0, 48.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [6.0, -72.0, 50.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [6.0, -72.0, 52.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [6.0, -70.0, 50.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [6.0, -70.0, 52.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [6.0, -68.0, 48.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [6.0, -68.0, 50.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [6.0, -68.0, 52.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [8.0, -76.0, 50.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [8.0, -72.0, 54.0]  // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [8.0, -70.0, 52.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [8.0, -70.0, 54.0]  // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [8.0, -68.0, 48.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [8.0, -68.0, 50.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [8.0, -68.0, 52.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [10.0, -68.0, 48.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [10.0, -68.0, 52.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [12.0, -62.0, 58.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [14.0, -66.0, 58.0]  // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [14.0, -64.0, 56.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [14.0, -64.0, 58.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [14.0, -64.0, 60.0]  // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [14.0, -62.0, 56.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [14.0, -62.0, 58.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [14.0, -62.0, 60.0]  // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [14.0, -60.0, 60.0]  // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Precuneus_R (aal)
# [16.0, -68.0, 58.0]  // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [16.0, -66.0, 60.0]  // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [16.0, -64.0, 56.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [16.0, -64.0, 58.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [16.0, -64.0, 60.0]  // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [16.0, -64.0, 62.0]  // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [18.0, -68.0, 56.0]  // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [18.0, -68.0, 58.0]  // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [18.0, -66.0, 60.0]  // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [18.0, -66.0, 62.0]  // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [18.0, -64.0, 54.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [18.0, -64.0, 56.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [18.0, -64.0, 58.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [18.0, -62.0, 54.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [18.0, -62.0, 56.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [18.0, -62.0, 58.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [18.0, -60.0, 56.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [18.0, -60.0, 58.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [20.0, -66.0, 56.0]  // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [20.0, -66.0, 58.0]  // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [20.0, -66.0, 60.0]  // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [20.0, -64.0, 54.0]  // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [20.0, -64.0, 56.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [20.0, -64.0, 58.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [20.0, -62.0, 56.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [20.0, -62.0, 58.0]  // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [22.0, -64.0, 56.0]  // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
# [22.0, -64.0, 58.0]  // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)
#
# Combo:  [5]
# [-38.0, -36.0, 16.0]  // Left Cerebrum // Temporal Lobe // Superior Temporal Gyrus // Gray Matter // brodmann area 41 // Rolandic_Oper_L (aal)
# [-38.0, -34.0, 18.0]  // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // Rolandic_Oper_L (aal)
# [-38.0, -34.0, 20.0]  // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // Rolandic_Oper_L (aal)
# [-36.0, -36.0, 18.0]  // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // Rolandic_Oper_L (aal)
# [-36.0, -36.0, 20.0]  // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined
# [-36.0, -34.0, 16.0]  // Left Cerebrum // Temporal Lobe // Superior Temporal Gyrus // Gray Matter // brodmann area 41 // Rolandic_Oper_L (aal)
# [-36.0, -34.0, 18.0]  // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // Rolandic_Oper_L (aal)
# [-36.0, -34.0, 20.0]  // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined
# [-34.0, -38.0, 18.0]  // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined
# [-34.0, -38.0, 20.0]  // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined
# [-34.0, -34.0, 18.0]  // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // Rolandic_Oper_L (aal)
# [-34.0, -34.0, 20.0]  // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined
# [-32.0, -38.0, 18.0]  // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined
# [-32.0, -38.0, 20.0]  // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined
# [-32.0, -36.0, 18.0]  // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined
# [-32.0, -36.0, 20.0]  // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined
#
# Combo:  [11]
# [-20.0, -24.0, 14.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Pulvinar // Thalamus_L (aal)
# [-20.0, -24.0, 16.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Pulvinar // undefined
# [-20.0, -22.0, 12.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)
# [-20.0, -22.0, 14.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)
# [-20.0, -22.0, 16.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // undefined
# [-20.0, -20.0, 12.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)
# [-20.0, -20.0, 14.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)
# [-20.0, -20.0, 16.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // undefined
# [-18.0, -24.0, 14.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Pulvinar // Thalamus_L (aal)
# [-18.0, -24.0, 16.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Pulvinar // undefined
# [-18.0, -22.0, 12.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)
# [-18.0, -22.0, 14.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)
# [-18.0, -22.0, 16.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // undefined
# [-18.0, -20.0, 12.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)
# [-18.0, -20.0, 14.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)
# [-18.0, -20.0, 16.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // undefined
# [-18.0, -18.0, 10.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)
# [-18.0, -18.0, 12.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)
# [-18.0, -18.0, 14.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)
# [-18.0, -18.0, 16.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // undefined
# [-18.0, -16.0, 12.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)
# [-16.0, -22.0, 12.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)
# [-16.0, -22.0, 14.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)
# [-16.0, -22.0, 16.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)
# [-16.0, -20.0, 10.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)
# [-16.0, -20.0, 12.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)
# [-16.0, -20.0, 14.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)
# [-16.0, -20.0, 16.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)
# [-16.0, -18.0, 10.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)
# [-16.0, -18.0, 12.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)
# [-16.0, -18.0, 14.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)
# [-16.0, -18.0, 16.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)
# [-16.0, -16.0, 10.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)
# [-16.0, -16.0, 12.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)
# [-16.0, -16.0, 14.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)
# [-14.0, -20.0, 12.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)
# [-14.0, -18.0, 14.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)
# [-14.0, -16.0, 10.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)
# [-14.0, -16.0, 12.0]  // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)
# [-8.0, 22.0, 40.0]  // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)
# [-8.0, 26.0, 40.0]  // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)
# [-6.0, 22.0, 38.0]  // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_L (aal)
# [-6.0, 22.0, 40.0]  // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)
# [-6.0, 22.0, 42.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)
# [-6.0, 26.0, 38.0]  // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)
# [-6.0, 26.0, 40.0]  // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)
# [-6.0, 26.0, 42.0]  // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)
# [-6.0, 28.0, 40.0]  // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)
# [-4.0, 20.0, 40.0]  // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)
# [-4.0, 22.0, 38.0]  // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_L (aal)
# [-4.0, 22.0, 40.0]  // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)
# [-4.0, 22.0, 42.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)
# [-4.0, 22.0, 44.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Supp_Motor_Area_L (aal)
# [-4.0, 24.0, 36.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_L (aal)
# [-4.0, 24.0, 38.0]  // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)
# [-4.0, 24.0, 40.0]  // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)
# [-4.0, 24.0, 42.0]  // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)
# [-4.0, 26.0, 36.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_L (aal)
# [-4.0, 26.0, 44.0]  // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 8 // Frontal_Sup_Medial_L (aal)
# [-4.0, 28.0, 38.0]  // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)
# [-4.0, 28.0, 40.0]  // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)
# [-4.0, 28.0, 42.0]  // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)
# [-2.0, 20.0, 38.0]  // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_L (aal)
# [-2.0, 20.0, 40.0]  // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)
# [-2.0, 20.0, 42.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)
# [-2.0, 22.0, 36.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_L (aal)
# [-2.0, 22.0, 38.0]  // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_L (aal)
# [-2.0, 22.0, 40.0]  // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)
# [-2.0, 24.0, 36.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_L (aal)
# [-2.0, 24.0, 38.0]  // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)
# [-2.0, 24.0, 40.0]  // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)
# [-2.0, 24.0, 42.0]  // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)
# [-2.0, 26.0, 36.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_L (aal)
# [-2.0, 26.0, 44.0]  // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 8 // Frontal_Sup_Medial_L (aal)
# [-2.0, 28.0, 36.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)
# [-2.0, 28.0, 38.0]  // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)
# [-2.0, 28.0, 40.0]  // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)
# [-2.0, 28.0, 42.0]  // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)
# [-2.0, 28.0, 44.0]  // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 8 // Frontal_Sup_Medial_L (aal)
# [-2.0, 30.0, 40.0]  // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)
# [0.0, 2.0, -2.0]  // Inter-Hemispheric // undefined // undefined // White Matter // Anterior Commissure // undefined
# [2.0, 2.0, -4.0]  // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 25 // undefined
# [2.0, 2.0, -2.0]  // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Anterior Commissure // undefined
# [2.0, 6.0, -4.0]  // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 25 // undefined
# [4.0, 2.0, -2.0]  // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Anterior Commissure // undefined
# [4.0, 4.0, -4.0]  // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 25 // undefined
# [4.0, 4.0, 4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, 4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 10.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 10.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 10.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 24.0, 38.0]  // Right Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_R (aal)
# [4.0, 24.0, 40.0]  // Right Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_R (aal)
# [4.0, 24.0, 42.0]  // Right Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_R (aal)
# [6.0, 2.0, -2.0]  // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Anterior Commissure // undefined
# [6.0, 2.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 2.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 2.0, 4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, 4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 8.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 8.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 8.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 8.0, 4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 10.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 10.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 10.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 4.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 4.0, 4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 6.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 6.0, 4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [8.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [8.0, 8.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [8.0, 8.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [8.0, 10.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [10.0, 0.0, 2.0]  // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Medial Globus Pallidus // undefined
# [10.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [10.0, 6.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
#
# Combo:  [8]
# [-40.0, 22.0, 0.0]  // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Insula_L (aal)
# [-38.0, 20.0, 2.0]  // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // Insula_L (aal)
# [-38.0, 22.0, 0.0]  // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Insula_L (aal)
# [-38.0, 24.0, 2.0]  // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Frontal_Inf_Tri_L (aal)
# [-38.0, 26.0, 2.0]  // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Frontal_Inf_Tri_L (aal)
# [-36.0, 20.0, 0.0]  // Left Cerebrum // Sub-lobar // Extra-Nuclear // Gray Matter // brodmann area 47 // Insula_L (aal)
# [-36.0, 22.0, 0.0]  // Left Cerebrum // Sub-lobar // Extra-Nuclear // Gray Matter // brodmann area 47 // Insula_L (aal)
# [-36.0, 22.0, 2.0]  // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // Insula_L (aal)
# [-36.0, 22.0, 4.0]  // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // Insula_L (aal)
# [-36.0, 24.0, 4.0]  // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 45 // Insula_L (aal)
# [-36.0, 26.0, 2.0]  // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Frontal_Inf_Tri_L (aal)
# [-34.0, 20.0, 0.0]  // Left Cerebrum // Sub-lobar // Extra-Nuclear // Gray Matter // brodmann area 47 // Insula_L (aal)
# [-34.0, 22.0, 2.0]  // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // Insula_L (aal)
# [-34.0, 26.0, 2.0]  // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Insula_L (aal)
# [-10.0, 32.0, 2.0]  // Left Cerebrum // Frontal Lobe // Sub-Gyral // White Matter // Corpus Callosum // undefined
# [-8.0, 32.0, 6.0]  // Left Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Corpus Callosum // undefined
# [-6.0, 32.0, 2.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // undefined
# [-6.0, 32.0, 4.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // undefined
# [-6.0, 32.0, 6.0]  // Left Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Corpus Callosum // undefined
# [-6.0, 32.0, 8.0]  // Left Cerebrum // Frontal Lobe // Sub-Gyral // White Matter // Corpus Callosum // undefined
# [-6.0, 32.0, 10.0]  // Left Cerebrum // Frontal Lobe // Sub-Gyral // White Matter // Corpus Callosum // undefined
# [-6.0, 34.0, 6.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // undefined
# [-4.0, -38.0, 26.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 31 // Cingulum_Post_L (aal)
# [-4.0, -38.0, 28.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 31 // Cingulum_Post_L (aal)
# [-4.0, -38.0, 30.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 31 // Cingulum_Post_L (aal)
# [-4.0, -36.0, 24.0]  // Left Cerebrum // Limbic Lobe // Posterior Cingulate // Gray Matter // brodmann area 23 // undefined
# [-4.0, -36.0, 26.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // undefined
# [-4.0, -36.0, 28.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // Cingulum_Post_L (aal)
# [-4.0, -36.0, 30.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // Cingulum_Post_L (aal)
# [-4.0, -34.0, 24.0]  // Left Cerebrum // Limbic Lobe // Posterior Cingulate // Gray Matter // brodmann area 23 // undefined
# [-4.0, -32.0, 24.0]  // Left Cerebrum // Limbic Lobe // Posterior Cingulate // Gray Matter // brodmann area 23 // undefined
# [-4.0, -32.0, 26.0]  // Left Cerebrum // Limbic Lobe // Posterior Cingulate // Gray Matter // brodmann area 23 // undefined
# [-4.0, -30.0, 26.0]  // Left Cerebrum // Limbic Lobe // Posterior Cingulate // Gray Matter // brodmann area 23 // undefined
# [-4.0, 32.0, 2.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // undefined
# [-4.0, 32.0, 4.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // undefined
# [-4.0, 32.0, 6.0]  // Left Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Corpus Callosum // undefined
# [-4.0, 32.0, 8.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // White Matter // Corpus Callosum // undefined
# [-4.0, 32.0, 10.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // White Matter // Corpus Callosum // undefined
# [-4.0, 32.0, 12.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)
# [-4.0, 34.0, 6.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // undefined
# [-4.0, 34.0, 8.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)
# [-4.0, 34.0, 10.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)
# [-4.0, 34.0, 12.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)
# [-4.0, 36.0, 6.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)
# [-2.0, -38.0, 26.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 31 // Cingulum_Post_L (aal)
# [-2.0, -38.0, 28.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 31 // Cingulum_Post_L (aal)
# [-2.0, -38.0, 30.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 31 // Cingulum_Post_L (aal)
# [-2.0, -38.0, 32.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 31 // Cingulum_Post_L (aal)
# [-2.0, -36.0, 26.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // undefined
# [-2.0, -36.0, 28.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // Cingulum_Post_L (aal)
# [-2.0, -36.0, 30.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // Cingulum_Post_L (aal)
# [-2.0, -36.0, 32.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 31 // Cingulum_Post_L (aal)
# [-2.0, -34.0, 26.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // undefined
# [-2.0, -34.0, 28.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // Cingulum_Post_L (aal)
# [-2.0, -34.0, 30.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // Cingulum_Post_L (aal)
# [-2.0, -34.0, 32.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 31 // Cingulum_Post_L (aal)
# [-2.0, -32.0, 28.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // undefined
# [-2.0, -32.0, 30.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // Cingulum_Post_L (aal)
# [-2.0, -32.0, 32.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 31 // Cingulum_Post_L (aal)
# [-2.0, -30.0, 28.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // undefined
# [-2.0, -30.0, 30.0]  // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // undefined
# [-2.0, 32.0, 6.0]  // Left Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Corpus Callosum // undefined
# [-2.0, 32.0, 8.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // White Matter // Corpus Callosum // undefined
# [-2.0, 32.0, 10.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // White Matter // Corpus Callosum // undefined
# [-2.0, 32.0, 12.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)
# [-2.0, 32.0, 14.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)
# [-2.0, 34.0, 8.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)
# [-2.0, 34.0, 10.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)
# [-2.0, 34.0, 12.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)
# [-2.0, 34.0, 14.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)
# [-2.0, 36.0, 6.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)
# [-2.0, 36.0, 8.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)
# [-2.0, 36.0, 10.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)
# [-2.0, 36.0, 12.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)
# [-2.0, 36.0, 14.0]  // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 32 // Cingulum_Ant_L (aal)
# [0.0, 32.0, 10.0]  // Inter-Hemispheric // undefined // undefined // White Matter // Corpus Callosum // undefined
# [2.0, 32.0, 14.0]  // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_R (aal)
# [2.0, 32.0, 16.0]  // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_R (aal)
# [2.0, 34.0, 12.0]  // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)
# [2.0, 36.0, 12.0]  // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)
# [2.0, 36.0, 14.0]  // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 32 // Cingulum_Ant_L (aal)
# [2.0, 36.0, 16.0]  // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 32 // Cingulum_Ant_L (aal)
# [4.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 10.0, -6.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [4.0, 10.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [4.0, 10.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 10.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 10.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 34.0, 14.0]  // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_R (aal)
# [4.0, 34.0, 16.0]  // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_R (aal)
# [6.0, 4.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 8.0, -6.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 8.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 8.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 8.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 10.0, -6.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 10.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 10.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 10.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 10.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 12.0, -8.0]  // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 25 // Caudate_R (aal)
# [6.0, 12.0, -6.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 12.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [8.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 6.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 8.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [8.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [8.0, 8.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [8.0, 8.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [8.0, 10.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [8.0, 10.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [8.0, 10.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [28.0, 20.0, -4.0]  // Right Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined
# [28.0, 20.0, -2.0]  // Right Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // Putamen_R (aal)
# [30.0, 18.0, -4.0]  // Right Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined
# [30.0, 18.0, -2.0]  // Right Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined
# [30.0, 20.0, -2.0]  // Right Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 47 // undefined
# [32.0, 16.0, 0.0]  // Right Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 47 // undefined
# [38.0, 2.0, 30.0]  // Right Cerebrum // Frontal Lobe // Precentral Gyrus // Gray Matter // brodmann area 6 // Precentral_R (aal)
# [38.0, 2.0, 32.0]  // Right Cerebrum // Frontal Lobe // Precentral Gyrus // Gray Matter // brodmann area 6 // Precentral_R (aal)
# [38.0, 4.0, 32.0]  // Right Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 9 // Precentral_R (aal)
# [42.0, 0.0, 30.0]  // Right Cerebrum // Frontal Lobe // Precentral Gyrus // Gray Matter // brodmann area 6 // undefined
# [42.0, 0.0, 32.0]  // Right Cerebrum // Frontal Lobe // Precentral Gyrus // Gray Matter // brodmann area 6 // Precentral_R (aal)
# [42.0, 2.0, 30.0]  // Right Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 9 // Precentral_R (aal)
# [42.0, 2.0, 32.0]  // Right Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 9 // Precentral_R (aal)
# [44.0, 2.0, 30.0]  // Right Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 9 // Precentral_R (aal)
# [44.0, 2.0, 32.0]  // Right Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 9 // Precentral_R (aal)
# [46.0, 2.0, 34.0]  // Right Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 9 // Precentral_R (aal)
#
# Combo:  [4]
# [-38.0, 30.0, -12.0]  // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Frontal_Inf_Orb_L (aal)
# [-38.0, 32.0, -12.0]  // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Frontal_Inf_Orb_L (aal)
# [-36.0, 30.0, -12.0]  // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Frontal_Inf_Orb_L (aal)
# [-36.0, 30.0, -10.0]  // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Frontal_Inf_Orb_L (aal)
# [-36.0, 32.0, -14.0]  // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Frontal_Inf_Orb_L (aal)
# [-36.0, 32.0, -12.0]  // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Frontal_Inf_Orb_L (aal)
# [-36.0, 32.0, -10.0]  // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Frontal_Inf_Orb_L (aal)
# [-34.0, 30.0, -10.0]  // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Frontal_Inf_Orb_L (aal)
# [-34.0, 32.0, -12.0]  // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Frontal_Inf_Orb_L (aal)
# [-32.0, 18.0, -8.0]  // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Insula_L (aal)
# [-32.0, 20.0, -10.0]  // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Insula_L (aal)
# ...
# [6.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 8.0, -6.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 8.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 10.0, -6.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 10.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 12.0, -8.0]  // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 25 // Caudate_R (aal)
# [8.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 8.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
#
# Combo:  [3, 4, 11]
# [2.0, 2.0, -2.0]  // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Anterior Commissure // undefined
# [2.0, 6.0, -4.0]  // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 25 // undefined
# [4.0, 2.0, -2.0]  // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Anterior Commissure // undefined
# [4.0, 4.0, -4.0]  // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 25 // undefined
# [4.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 2.0, -2.0]  // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Anterior Commissure // undefined
# [6.0, 2.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 2.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 8.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
#
# Combo:  [3, 8, 11]
# [4.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 8.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
#
# Combo:  [3, 8, 10, 11]
# [4.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 8.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
#
# Combo:  [3, 4, 8, 11]
# [4.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 8.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
#
# Combo:  [3, 4, 10, 11]
# [2.0, 2.0, -2.0]  // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Anterior Commissure // undefined
# [2.0, 6.0, -4.0]  // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 25 // undefined
# [4.0, 2.0, -2.0]  // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Anterior Commissure // undefined
# [4.0, 4.0, -4.0]  // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 25 // undefined
# [4.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 2.0, -2.0]  // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Anterior Commissure // undefined
# [6.0, 2.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 2.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 8.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
#
# Combo:  [4, 8, 10, 11]
# [4.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 10.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 10.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 10.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 8.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 8.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 8.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 10.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 10.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 10.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 6.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [8.0, 8.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [8.0, 8.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [8.0, 10.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
#
# Combo:  [3, 4, 8, 10]
# [4.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 10.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 4.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 8.0, -6.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 8.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 10.0, -6.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 10.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [8.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 8.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
#
# Combo:  [3, 4, 8, 10, 11]
# [4.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 6.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [4.0, 8.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 4.0, 2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 6.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [6.0, 8.0, -4.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)
# [6.0, 8.0, -2.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined
# [8.0, 4.0, 0.0]  // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined

# %%
display(one_line_lst_parsed_2)
# Out:
# {'[2]': [[[-36.0, -70.0, 42.0],
#    ' // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Angular_L (aal)'],
#   [[-36.0, -68.0, 40.0],
#    ' // Left Cerebrum // Parietal Lobe // Inferior Parietal Lobule // Gray Matter // brodmann area 39 // Angular_L (aal)'],
#   [[-36.0, -68.0, 42.0],
#    ' // Left Cerebrum // Parietal Lobe // Inferior Parietal Lobule // Gray Matter // brodmann area 39 // Angular_L (aal)'],
#   [[-36.0, -68.0, 44.0],
#    ' // Left Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Angular_L (aal)'],
#   [[-36.0, -66.0, 42.0],
#    ' // Left Cerebrum // Parietal Lobe // Inferior Parietal Lobule // Gray Matter // brodmann area 39 // Angular_L (aal)'],
#   [[-34.0, -70.0, 40.0],
#    ' // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)'],
#   [[-34.0, -70.0, 42.0],
#    ' // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)'],
#   [[-34.0, -70.0, 44.0],
#    ' // Left Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Angular_L (aal)'],
#   [[-34.0, -68.0, 40.0],
#    ' // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)'],
#   [[-34.0, -68.0, 42.0],
#    ' // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)'],
#   [[-34.0, -68.0, 44.0],
#    ' // Left Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Angular_L (aal)'],
#   [[-34.0, -68.0, 46.0],
#    ' // Left Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Inf_L (aal)'],
#   [[-34.0, -66.0, 40.0],
#    ' // Left Cerebrum // Parietal Lobe // Inferior Parietal Lobule // Gray Matter // brodmann area 39 // Occipital_Mid_L (aal)'],
#   [[-34.0, -66.0, 42.0],
#    ' // Left Cerebrum // Parietal Lobe // Inferior Parietal Lobule // Gray Matter // brodmann area 39 // Angular_L (aal)'],
#   [[-34.0, -66.0, 44.0],
#    ' // Left Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Inf_L (aal)'],
#   [[-32.0, -74.0, 42.0],
#    ' // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)'],
#   [[-32.0, -68.0, 38.0],
#    ' // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Occipital_Mid_L (aal)'],
#   [[-32.0, -68.0, 40.0],
#    ' // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)'],
#   [[-32.0, -68.0, 42.0],
#    ' // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)'],
#   [[-32.0, -66.0, 40.0],
#    ' // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)'],
#   [[-32.0, -66.0, 42.0],
#    ' // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)'],
#   [[-32.0, -66.0, 44.0],
#    ' // Left Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Inf_L (aal)'],
#   [[-32.0, -66.0, 46.0],
#    ' // Left Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Inf_L (aal)'],
#   [[-30.0, -74.0, 40.0],
#    ' // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Occipital_Mid_L (aal)'],
#   [[-30.0, -74.0, 42.0],
#    ' // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)'],
#   [[-28.0, -74.0, 42.0],
#    ' // Left Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 19 // Parietal_Inf_L (aal)'],
#   [[4.0, -72.0, 50.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[4.0, -70.0, 50.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[6.0, -74.0, 48.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[6.0, -74.0, 50.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[6.0, -74.0, 52.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[6.0, -72.0, 48.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[6.0, -72.0, 50.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[6.0, -72.0, 52.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[6.0, -70.0, 50.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[6.0, -70.0, 52.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[6.0, -68.0, 48.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[6.0, -68.0, 50.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[6.0, -68.0, 52.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[8.0, -76.0, 50.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[8.0, -72.0, 54.0],
#    ' // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[8.0, -70.0, 52.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[8.0, -70.0, 54.0],
#    ' // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[8.0, -68.0, 48.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[8.0, -68.0, 50.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[8.0, -68.0, 52.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[10.0, -68.0, 48.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[10.0, -68.0, 52.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[12.0, -62.0, 58.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[14.0, -66.0, 58.0],
#    ' // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[14.0, -64.0, 56.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[14.0, -64.0, 58.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[14.0, -64.0, 60.0],
#    ' // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[14.0, -62.0, 56.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[14.0, -62.0, 58.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[14.0, -62.0, 60.0],
#    ' // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[14.0, -60.0, 60.0],
#    ' // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Precuneus_R (aal)'],
#   [[16.0, -68.0, 58.0],
#    ' // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[16.0, -66.0, 60.0],
#    ' // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[16.0, -64.0, 56.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[16.0, -64.0, 58.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[16.0, -64.0, 60.0],
#    ' // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[16.0, -64.0, 62.0],
#    ' // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[18.0, -68.0, 56.0],
#    ' // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[18.0, -68.0, 58.0],
#    ' // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[18.0, -66.0, 60.0],
#    ' // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[18.0, -66.0, 62.0],
#    ' // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[18.0, -64.0, 54.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[18.0, -64.0, 56.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[18.0, -64.0, 58.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[18.0, -62.0, 54.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[18.0, -62.0, 56.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[18.0, -62.0, 58.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[18.0, -60.0, 56.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[18.0, -60.0, 58.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[20.0, -66.0, 56.0],
#    ' // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[20.0, -66.0, 58.0],
#    ' // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[20.0, -66.0, 60.0],
#    ' // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[20.0, -64.0, 54.0],
#    ' // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[20.0, -64.0, 56.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[20.0, -64.0, 58.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[20.0, -62.0, 56.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[20.0, -62.0, 58.0],
#    ' // Right Cerebrum // Parietal Lobe // Precuneus // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[22.0, -64.0, 56.0],
#    ' // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)'],
#   [[22.0, -64.0, 58.0],
#    ' // Right Cerebrum // Parietal Lobe // Superior Parietal Lobule // Gray Matter // brodmann area 7 // Parietal_Sup_R (aal)']],
#  '[5]': [[[-38.0, -36.0, 16.0],
#    ' // Left Cerebrum // Temporal Lobe // Superior Temporal Gyrus // Gray Matter // brodmann area 41 // Rolandic_Oper_L (aal)'],
#   [[-38.0, -34.0, 18.0],
#    ' // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // Rolandic_Oper_L (aal)'],
#   [[-38.0, -34.0, 20.0],
#    ' // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // Rolandic_Oper_L (aal)'],
#   [[-36.0, -36.0, 18.0],
#    ' // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // Rolandic_Oper_L (aal)'],
#   [[-36.0, -36.0, 20.0],
#    ' // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined'],
#   [[-36.0, -34.0, 16.0],
#    ' // Left Cerebrum // Temporal Lobe // Superior Temporal Gyrus // Gray Matter // brodmann area 41 // Rolandic_Oper_L (aal)'],
#   [[-36.0, -34.0, 18.0],
#    ' // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // Rolandic_Oper_L (aal)'],
#   [[-36.0, -34.0, 20.0],
#    ' // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined'],
#   [[-34.0, -38.0, 18.0],
#    ' // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined'],
#   [[-34.0, -38.0, 20.0],
#    ' // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined'],
#   [[-34.0, -34.0, 18.0],
#    ' // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // Rolandic_Oper_L (aal)'],
#   [[-34.0, -34.0, 20.0],
#    ' // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined'],
#   [[-32.0, -38.0, 18.0],
#    ' // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined'],
#   [[-32.0, -38.0, 20.0],
#    ' // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined'],
#   [[-32.0, -36.0, 18.0],
#    ' // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined'],
#   [[-32.0, -36.0, 20.0],
#    ' // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // undefined']],
#  '[11]': [[[-20.0, -24.0, 14.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Pulvinar // Thalamus_L (aal)'],
#   [[-20.0, -24.0, 16.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Pulvinar // undefined'],
#   [[-20.0, -22.0, 12.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)'],
#   [[-20.0, -22.0, 14.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)'],
#   [[-20.0, -22.0, 16.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // undefined'],
#   [[-20.0, -20.0, 12.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)'],
#   [[-20.0, -20.0, 14.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)'],
#   [[-20.0, -20.0, 16.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // undefined'],
#   [[-18.0, -24.0, 14.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Pulvinar // Thalamus_L (aal)'],
#   [[-18.0, -24.0, 16.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Pulvinar // undefined'],
#   [[-18.0, -22.0, 12.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)'],
#   [[-18.0, -22.0, 14.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)'],
#   [[-18.0, -22.0, 16.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // undefined'],
#   [[-18.0, -20.0, 12.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)'],
#   [[-18.0, -20.0, 14.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)'],
#   [[-18.0, -20.0, 16.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // undefined'],
#   [[-18.0, -18.0, 10.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)'],
#   [[-18.0, -18.0, 12.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)'],
#   [[-18.0, -18.0, 14.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)'],
#   [[-18.0, -18.0, 16.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // undefined'],
#   [[-18.0, -16.0, 12.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)'],
#   [[-16.0, -22.0, 12.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)'],
#   [[-16.0, -22.0, 14.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)'],
#   [[-16.0, -22.0, 16.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)'],
#   [[-16.0, -20.0, 10.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)'],
#   [[-16.0, -20.0, 12.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)'],
#   [[-16.0, -20.0, 14.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)'],
#   [[-16.0, -20.0, 16.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)'],
#   [[-16.0, -18.0, 10.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)'],
#   [[-16.0, -18.0, 12.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)'],
#   [[-16.0, -18.0, 14.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)'],
#   [[-16.0, -18.0, 16.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)'],
#   [[-16.0, -16.0, 10.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)'],
#   [[-16.0, -16.0, 12.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)'],
#   [[-16.0, -16.0, 14.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)'],
#   [[-14.0, -20.0, 12.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Lateral Posterior Nucleus // Thalamus_L (aal)'],
#   [[-14.0, -18.0, 14.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)'],
#   [[-14.0, -16.0, 10.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)'],
#   [[-14.0, -16.0, 12.0],
#    ' // Left Cerebrum // Sub-lobar // Thalamus // Gray Matter // Ventral Lateral Nucleus // Thalamus_L (aal)'],
#   [[-8.0, 22.0, 40.0],
#    ' // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)'],
#   [[-8.0, 26.0, 40.0],
#    ' // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)'],
#   [[-6.0, 22.0, 38.0],
#    ' // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_L (aal)'],
#   [[-6.0, 22.0, 40.0],
#    ' // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)'],
#   [[-6.0, 22.0, 42.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)'],
#   [[-6.0, 26.0, 38.0],
#    ' // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)'],
#   [[-6.0, 26.0, 40.0],
#    ' // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)'],
#   [[-6.0, 26.0, 42.0],
#    ' // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)'],
#   [[-6.0, 28.0, 40.0],
#    ' // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)'],
#   [[-4.0, 20.0, 40.0],
#    ' // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)'],
#   [[-4.0, 22.0, 38.0],
#    ' // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_L (aal)'],
#   [[-4.0, 22.0, 40.0],
#    ' // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)'],
#   [[-4.0, 22.0, 42.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)'],
#   [[-4.0, 22.0, 44.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Supp_Motor_Area_L (aal)'],
#   [[-4.0, 24.0, 36.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_L (aal)'],
#   [[-4.0, 24.0, 38.0],
#    ' // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)'],
#   [[-4.0, 24.0, 40.0],
#    ' // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)'],
#   [[-4.0, 24.0, 42.0],
#    ' // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)'],
#   [[-4.0, 26.0, 36.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_L (aal)'],
#   [[-4.0, 26.0, 44.0],
#    ' // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 8 // Frontal_Sup_Medial_L (aal)'],
#   [[-4.0, 28.0, 38.0],
#    ' // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)'],
#   [[-4.0, 28.0, 40.0],
#    ' // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)'],
#   [[-4.0, 28.0, 42.0],
#    ' // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)'],
#   [[-2.0, 20.0, 38.0],
#    ' // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_L (aal)'],
#   [[-2.0, 20.0, 40.0],
#    ' // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)'],
#   [[-2.0, 20.0, 42.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)'],
#   [[-2.0, 22.0, 36.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_L (aal)'],
#   [[-2.0, 22.0, 38.0],
#    ' // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_L (aal)'],
#   [[-2.0, 22.0, 40.0],
#    ' // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)'],
#   [[-2.0, 24.0, 36.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_L (aal)'],
#   [[-2.0, 24.0, 38.0],
#    ' // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)'],
#   [[-2.0, 24.0, 40.0],
#    ' // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)'],
#   [[-2.0, 24.0, 42.0],
#    ' // Left Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)'],
#   [[-2.0, 26.0, 36.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_L (aal)'],
#   [[-2.0, 26.0, 44.0],
#    ' // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 8 // Frontal_Sup_Medial_L (aal)'],
#   [[-2.0, 28.0, 36.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_L (aal)'],
#   [[-2.0, 28.0, 38.0],
#    ' // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)'],
#   [[-2.0, 28.0, 40.0],
#    ' // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)'],
#   [[-2.0, 28.0, 42.0],
#    ' // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)'],
#   [[-2.0, 28.0, 44.0],
#    ' // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 8 // Frontal_Sup_Medial_L (aal)'],
#   [[-2.0, 30.0, 40.0],
#    ' // Left Cerebrum // Frontal Lobe // Medial Frontal Gyrus // Gray Matter // brodmann area 6 // Frontal_Sup_Medial_L (aal)'],
#   [[0.0, 2.0, -2.0],
#    ' // Inter-Hemispheric // undefined // undefined // White Matter // Anterior Commissure // undefined'],
#   [[2.0, 2.0, -4.0],
#    ' // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 25 // undefined'],
#   [[2.0, 2.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Anterior Commissure // undefined'],
#   [[2.0, 6.0, -4.0],
#    ' // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 25 // undefined'],
#   [[4.0, 2.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Anterior Commissure // undefined'],
#   [[4.0, 4.0, -4.0],
#    ' // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 25 // undefined'],
#   [[4.0, 4.0, 4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, 4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 10.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 10.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 10.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 24.0, 38.0],
#    ' // Right Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_R (aal)'],
#   [[4.0, 24.0, 40.0],
#    ' // Right Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Cingulum_Mid_R (aal)'],
#   [[4.0, 24.0, 42.0],
#    ' // Right Cerebrum // Frontal Lobe // Cingulate Gyrus // Gray Matter // brodmann area 32 // Frontal_Sup_Medial_R (aal)'],
#   [[6.0, 2.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Anterior Commissure // undefined'],
#   [[6.0, 2.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 2.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 2.0, 4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, 4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 8.0, -4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[6.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 8.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 8.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 8.0, 4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 10.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[6.0, 10.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 10.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[8.0, 4.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[8.0, 4.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[8.0, 4.0, 4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[8.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[8.0, 6.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[8.0, 6.0, 4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[8.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[8.0, 8.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[8.0, 8.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[8.0, 10.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[10.0, 0.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Medial Globus Pallidus // undefined'],
#   [[10.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[10.0, 6.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined']],
#  '[8]': [[[-40.0, 22.0, 0.0],
#    ' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Insula_L (aal)'],
#   [[-38.0, 20.0, 2.0],
#    ' // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // Insula_L (aal)'],
#   [[-38.0, 22.0, 0.0],
#    ' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Insula_L (aal)'],
#   [[-38.0, 24.0, 2.0],
#    ' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Frontal_Inf_Tri_L (aal)'],
#   [[-38.0, 26.0, 2.0],
#    ' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Frontal_Inf_Tri_L (aal)'],
#   [[-36.0, 20.0, 0.0],
#    ' // Left Cerebrum // Sub-lobar // Extra-Nuclear // Gray Matter // brodmann area 47 // Insula_L (aal)'],
#   [[-36.0, 22.0, 0.0],
#    ' // Left Cerebrum // Sub-lobar // Extra-Nuclear // Gray Matter // brodmann area 47 // Insula_L (aal)'],
#   [[-36.0, 22.0, 2.0],
#    ' // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // Insula_L (aal)'],
#   [[-36.0, 22.0, 4.0],
#    ' // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // Insula_L (aal)'],
#   [[-36.0, 24.0, 4.0],
#    ' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 45 // Insula_L (aal)'],
#   [[-36.0, 26.0, 2.0],
#    ' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Frontal_Inf_Tri_L (aal)'],
#   [[-34.0, 20.0, 0.0],
#    ' // Left Cerebrum // Sub-lobar // Extra-Nuclear // Gray Matter // brodmann area 47 // Insula_L (aal)'],
#   [[-34.0, 22.0, 2.0],
#    ' // Left Cerebrum // Sub-lobar // Insula // Gray Matter // brodmann area 13 // Insula_L (aal)'],
#   [[-34.0, 26.0, 2.0],
#    ' // Left Cerebrum // Frontal Lobe // Inferior Frontal Gyrus // Gray Matter // brodmann area 47 // Insula_L (aal)'],
#   [[-10.0, 32.0, 2.0],
#    ' // Left Cerebrum // Frontal Lobe // Sub-Gyral // White Matter // Corpus Callosum // undefined'],
#   [[-8.0, 32.0, 6.0],
#    ' // Left Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Corpus Callosum // undefined'],
#   [[-6.0, 32.0, 2.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // undefined'],
#   [[-6.0, 32.0, 4.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // undefined'],
#   [[-6.0, 32.0, 6.0],
#    ' // Left Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Corpus Callosum // undefined'],
#   [[-6.0, 32.0, 8.0],
#    ' // Left Cerebrum // Frontal Lobe // Sub-Gyral // White Matter // Corpus Callosum // undefined'],
#   [[-6.0, 32.0, 10.0],
#    ' // Left Cerebrum // Frontal Lobe // Sub-Gyral // White Matter // Corpus Callosum // undefined'],
#   [[-6.0, 34.0, 6.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // undefined'],
#   [[-4.0, -38.0, 26.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 31 // Cingulum_Post_L (aal)'],
#   [[-4.0, -38.0, 28.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 31 // Cingulum_Post_L (aal)'],
#   [[-4.0, -38.0, 30.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 31 // Cingulum_Post_L (aal)'],
#   [[-4.0, -36.0, 24.0],
#    ' // Left Cerebrum // Limbic Lobe // Posterior Cingulate // Gray Matter // brodmann area 23 // undefined'],
#   [[-4.0, -36.0, 26.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // undefined'],
#   [[-4.0, -36.0, 28.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // Cingulum_Post_L (aal)'],
#   [[-4.0, -36.0, 30.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // Cingulum_Post_L (aal)'],
#   [[-4.0, -34.0, 24.0],
#    ' // Left Cerebrum // Limbic Lobe // Posterior Cingulate // Gray Matter // brodmann area 23 // undefined'],
#   [[-4.0, -32.0, 24.0],
#    ' // Left Cerebrum // Limbic Lobe // Posterior Cingulate // Gray Matter // brodmann area 23 // undefined'],
#   [[-4.0, -32.0, 26.0],
#    ' // Left Cerebrum // Limbic Lobe // Posterior Cingulate // Gray Matter // brodmann area 23 // undefined'],
#   [[-4.0, -30.0, 26.0],
#    ' // Left Cerebrum // Limbic Lobe // Posterior Cingulate // Gray Matter // brodmann area 23 // undefined'],
#   [[-4.0, 32.0, 2.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // undefined'],
#   [[-4.0, 32.0, 4.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // undefined'],
#   [[-4.0, 32.0, 6.0],
#    ' // Left Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Corpus Callosum // undefined'],
#   [[-4.0, 32.0, 8.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // White Matter // Corpus Callosum // undefined'],
#   [[-4.0, 32.0, 10.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // White Matter // Corpus Callosum // undefined'],
#   [[-4.0, 32.0, 12.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)'],
#   [[-4.0, 34.0, 6.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // undefined'],
#   [[-4.0, 34.0, 8.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)'],
#   [[-4.0, 34.0, 10.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)'],
#   [[-4.0, 34.0, 12.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)'],
#   [[-4.0, 36.0, 6.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)'],
#   [[-2.0, -38.0, 26.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 31 // Cingulum_Post_L (aal)'],
#   [[-2.0, -38.0, 28.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 31 // Cingulum_Post_L (aal)'],
#   [[-2.0, -38.0, 30.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 31 // Cingulum_Post_L (aal)'],
#   [[-2.0, -38.0, 32.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 31 // Cingulum_Post_L (aal)'],
#   [[-2.0, -36.0, 26.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // undefined'],
#   [[-2.0, -36.0, 28.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // Cingulum_Post_L (aal)'],
#   [[-2.0, -36.0, 30.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // Cingulum_Post_L (aal)'],
#   [[-2.0, -36.0, 32.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 31 // Cingulum_Post_L (aal)'],
#   [[-2.0, -34.0, 26.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // undefined'],
#   [[-2.0, -34.0, 28.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // Cingulum_Post_L (aal)'],
#   [[-2.0, -34.0, 30.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // Cingulum_Post_L (aal)'],
#   [[-2.0, -34.0, 32.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 31 // Cingulum_Post_L (aal)'],
#   [[-2.0, -32.0, 28.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // undefined'],
#   [[-2.0, -32.0, 30.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // Cingulum_Post_L (aal)'],
#   [[-2.0, -32.0, 32.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 31 // Cingulum_Post_L (aal)'],
#   [[-2.0, -30.0, 28.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // undefined'],
#   [[-2.0, -30.0, 30.0],
#    ' // Left Cerebrum // Limbic Lobe // Cingulate Gyrus // Gray Matter // brodmann area 23 // undefined'],
#   [[-2.0, 32.0, 6.0],
#    ' // Left Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Corpus Callosum // undefined'],
#   [[-2.0, 32.0, 8.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // White Matter // Corpus Callosum // undefined'],
#   [[-2.0, 32.0, 10.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // White Matter // Corpus Callosum // undefined'],
#   [[-2.0, 32.0, 12.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)'],
#   [[-2.0, 32.0, 14.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)'],
#   [[-2.0, 34.0, 8.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)'],
#   [[-2.0, 34.0, 10.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)'],
#   [[-2.0, 34.0, 12.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)'],
#   [[-2.0, 34.0, 14.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)'],
#   [[-2.0, 36.0, 6.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)'],
#   [[-2.0, 36.0, 8.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)'],
#   [[-2.0, 36.0, 10.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)'],
#   [[-2.0, 36.0, 12.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)'],
#   [[-2.0, 36.0, 14.0],
#    ' // Left Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 32 // Cingulum_Ant_L (aal)'],
#   [[0.0, 32.0, 10.0],
#    ' // Inter-Hemispheric // undefined // undefined // White Matter // Corpus Callosum // undefined'],
#   [[2.0, 32.0, 14.0],
#    ' // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_R (aal)'],
#   [[2.0, 32.0, 16.0],
#    ' // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_R (aal)'],
#   [[2.0, 34.0, 12.0],
#    ' // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)'],
#   [[2.0, 36.0, 12.0],
#    ' // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_L (aal)'],
#   [[2.0, 36.0, 14.0],
#    ' // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 32 // Cingulum_Ant_L (aal)'],
#   [[2.0, 36.0, 16.0],
#    ' // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 32 // Cingulum_Ant_L (aal)'],
#   [[4.0, 6.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 10.0, -6.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[4.0, 10.0, -4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[4.0, 10.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 10.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 10.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 34.0, 14.0],
#    ' // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_R (aal)'],
#   [[4.0, 34.0, 16.0],
#    ' // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 24 // Cingulum_Ant_R (aal)'],
#   [[6.0, 4.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 8.0, -6.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[6.0, 8.0, -4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[6.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 8.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 8.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 10.0, -6.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[6.0, 10.0, -4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[6.0, 10.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[6.0, 10.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 10.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 12.0, -8.0],
#    ' // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 25 // Caudate_R (aal)'],
#   [[6.0, 12.0, -6.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[6.0, 12.0, -4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[8.0, 4.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[8.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[8.0, 6.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[8.0, 8.0, -4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[8.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[8.0, 8.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[8.0, 8.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[8.0, 10.0, -4.0],
# ...
#   [[4.0, 4.0, -4.0],
#    ' // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 25 // undefined'],
#   [[4.0, 6.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 2.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Anterior Commissure // undefined'],
#   [[6.0, 2.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 2.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 8.0, -4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[6.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[8.0, 4.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined']],
#  '[3, 8, 11]': [[[4.0, 6.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 8.0, -4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[6.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[8.0, 4.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined']],
#  '[3, 8, 10, 11]': [[[4.0, 6.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 8.0, -4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[6.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[8.0, 4.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined']],
#  '[3, 4, 8, 11]': [[[4.0, 6.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 8.0, -4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[6.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[8.0, 4.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined']],
#  '[3, 4, 10, 11]': [[[2.0, 2.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Anterior Commissure // undefined'],
#   [[2.0, 6.0, -4.0],
#    ' // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 25 // undefined'],
#   [[4.0, 2.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Anterior Commissure // undefined'],
#   [[4.0, 4.0, -4.0],
#    ' // Right Cerebrum // Limbic Lobe // Anterior Cingulate // Gray Matter // brodmann area 25 // undefined'],
#   [[4.0, 6.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 2.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Extra-Nuclear // White Matter // Anterior Commissure // undefined'],
#   [[6.0, 2.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 2.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 8.0, -4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[6.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[8.0, 4.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined']],
#  '[4, 8, 10, 11]': [[[4.0, 6.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 10.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 10.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 10.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 8.0, -4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[6.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 8.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 8.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 10.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[6.0, 10.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 10.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[8.0, 4.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[8.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[8.0, 6.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[8.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[8.0, 8.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[8.0, 8.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[8.0, 10.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)']],
#  '[3, 4, 8, 10]': [[[4.0, 6.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 10.0, -4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[6.0, 4.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 8.0, -6.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[6.0, 8.0, -4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[6.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 10.0, -6.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[6.0, 10.0, -4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[8.0, 4.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[8.0, 8.0, -4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)']],
#  '[3, 4, 8, 10, 11]': [[[4.0, 6.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 6.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[4.0, 8.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 4.0, 2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 6.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[6.0, 8.0, -4.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // Caudate_R (aal)'],
#   [[6.0, 8.0, -2.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined'],
#   [[8.0, 4.0, 0.0],
#    ' // Right Cerebrum // Sub-lobar // Caudate // Gray Matter // Caudate Head // undefined']]}
